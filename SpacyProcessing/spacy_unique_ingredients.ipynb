# %%
import ast
from collections import Counter

import pandas as pd

COUNT_CUTOFF = 1500  # ingredients with less than this many occurances will be discarded

# %%
df = pd.read_csv("../data/SpacyProcessing/v1/foodkg_spacy_processed.csv")
df.head(5)
# Out:
#    recipe_id                               original_ingredients  \
# 0          0  ['1 c. firmly packed brown sugar', '1/2 c. eva...
# 1          1  ['1 small jar chipped beef, cut up', '4 boned ...
# 2          2  ['2 (16 oz.) pkg. frozen corn', '1 (8 oz.) pkg...
# 3          3  ['1 large whole chicken', '2 (10 1/2 oz.) cans...
# 4          4  ['1 c. peanut butter', '3/4 c. graham cracker ...
#
#                                processed_ingredients
# 0  ['brown sugar', 'milk', 'vanilla', 'nut', 'but...
# 1  ['beef', 'chicken breast', 'cream mushroom sou...
# 2  ['corn', 'cream cheese', 'butter', 'garlic', '...
# 3  ['chicken', 'chicken gravy', 'cream mushroom s...
# 4  ['peanut butter', 'graham cracker crumb', 'but...

# %%
# Ensure they're lists
df["ingredients_list"] = df["processed_ingredients"].apply(
    lambda x: ast.literal_eval(str(x)) if isinstance(x, str) else x
)
df["ingredients_list"].head(5)
# Out:
# 0    [brown sugar, milk, vanilla, nut, butter marga...
# 1    [beef, chicken breast, cream mushroom soup, ca...
# 2    [corn, cream cheese, butter, garlic, salt, pep...
# 3    [chicken, chicken gravy, cream mushroom soup, ...
# 4    [peanut butter, graham cracker crumb, butter, ...
# Name: ingredients_list, dtype: object

# %%
# Flatten all lists and deduplicate
counter = Counter()
for sublist in df["ingredients_list"]:
    counter.update(sublist)

ingredient_counts = dict(counter.most_common())  # sorted by most common first

# %%
filtered = [(item, count) for item, count in counter.most_common() if count > COUNT_CUTOFF]
print(len(filtered))
filtered
# Out:
# 1036
# [('salt', 888745),
#  ('sugar', 577971),
#  ('egg', 517357),
#  ('onion', 487377),
#  ('butter', 419128),
#  ('garlic', 402863),
#  ('water', 396995),
#  ('pepper', 341221),
#  ('flour', 335132),
#  ('milk', 319474),
#  ('olive oil', 205232),
#  ('vanilla', 198152),
#  ('brown sugar', 186386),
#  ('cinnamon', 180451),
#  ('tomato', 175215),
#  ('soda', 163642),
#  ('lemon juice', 155174),
#  ('black pepper', 142072),
#  ('allpurpose flour', 141563),
#  ('margarine', 122634),
#  ('carrot', 112995),
#  ('cream cheese', 111381),
#  ('sour cream', 111354),
#  ('celery', 110423),
#  ('parsley', 109995),
#  ('oil', 109153),
#  ('vegetable oil', 101458),
#  ('beef', 93784),
#  ('vanilla extract', 89973),
#  ('green onion', 86189),
#  ('parmesan cheese', 85009),
#  ('mayonnaise', 84026),
#  ('pecan', 83316),
#  ('cheddar cheese', 81506),
#  ('unsalted butter', 79754),
#  ('mushroom', 76213),
#  ('cream', 74740),
#  ('nutmeg', 74198),
#  ('kosher salt', 74070),
#  ('vinegar', 73783),
#  ('green pepper', 72739),
#  ('ginger', 72379),
#  ('nut', 71890),
#  ('basil', 69427),
#  ('honey', 68596),
#  ('virgin olive oil', 68519),
#  ('potato', 68220),
#  ('oregano', 68157),
#  ('chicken breast', 67616),
#  ('worcestershire', 66235),
#  ('thyme', 65981),
#  ('soy', 65531),
#  ('paprika', 59980),
#  ('cornstarch', 59800),
#  ('powdered sugar', 59198),
#  ('cumin', 58854),
#  ('chicken', 58615),
#  ('bacon', 58187),
#  ('chili', 57852),
#  ('pineapple', 57595),
#  ('chicken broth', 54378),
#  ('walnut', 53717),
#  ('granulated sugar', 52298),
#  ('shortening', 51715),
#  ('red onion', 51049),
#  ('freshly black pepper', 49026),
#  ('raisin', 47377),
#  ('egg yolk', 45920),
#  ('cilantro', 45403),
#  ('buttermilk', 45129),
#  ('lemon', 44747),
#  ('rice', 43854),
#  ('orange juice', 41857),
#  ('red pepper', 41649),
#  ('cocoa', 41159),
#  ('cheese', 41083),
#  ('banana', 40434),
#  ('lime juice', 39675),
#  ('cayenne pepper', 39441),
#  ('strawberry', 39069),
#  ('butter margarine', 38960),
#  ('apple', 38419),
#  ('broccoli', 37665),
#  ('cream mushroom soup', 36661),
#  ('mozzarella cheese', 36547),
#  ('almond', 36345),
#  ('juice', 35880),
#  ('mustard', 35180),
#  ('zucchini', 35150),
#  ('whipping cream', 34977),
#  ('dijon mustard', 34230),
#  ('cream chicken soup', 34027),
#  ('cool whip', 34017),
#  ('egg white', 33727),
#  ('canola oil', 33038),
#  ('spinach', 32692),
#  ('confectioner', 31960),
#  ('tomato paste', 31807),
#  ('cube', 31757),
#  ('scallion', 31324),
#  ('room temperature', 31265),
#  ('chocolate chip', 30893),
#  ('red bell pepper', 30879),
#  ('peanut butter', 29209),
#  ('red pepper flake', 28568),
#  ('shallot', 28499),
#  ('chicken stock', 28445),
#  ('corn', 27904),
#  ('shrimp', 27815),
#  ('garlic salt', 27551),
#  ('bread crumb', 27540),
#  ('ketchup', 27284),
#  ('dry mustard', 26447),
#  ('sea salt', 25939),
#  ('oleo', 25827),
#  ('cranberry', 25072),
#  ('wine', 25060),
#  ('bell pepper', 24939),
#  ('bread', 24904),
#  ('bay leaf', 24524),
#  ('coconut', 24213),
#  ('freshly pepper', 23615),
#  ('dry wine', 23474),
#  ('pea', 23331),
#  ('chive', 23076),
#  ('green bell pepper', 22892),
#  ('red wine vinegar', 22884),
#  ('balsamic vinegar', 22843),
#  ('cabbage', 22287),
#  ('mint', 21865),
#  ('bay', 21649),
#  ('yellow onion', 21501),
#  ('sharp cheddar cheese', 21492),
#  ('corn syrup', 21329),
#  ('cucumber', 20823),
#  ('curry', 20599),
#  ('wheat flour', 20034),
#  ('sesame oil', 20031),
#  ('blueberry', 19333),
#  ('green bean', 19246),
#  ('spaghetti', 18666),
#  ('cider vinegar', 18437),
#  ('ham', 18383),
#  ('sesame seed', 18282),
#  ('molasse', 18141),
#  ('turmeric', 17824),
#  ('peach', 17722),
#  ('semisweet chocolate chip', 17571),
#  ('jalapeno pepper', 17362),
#  ('coriander', 17345),
#  ('sweet potato', 17203),
#  ('dill', 17148),
#  ('lettuce', 16949),
#  ('green chilie', 16640),
#  ('turkey', 16570),
#  ('almond extract', 16521),
#  ('black olive', 16497),
#  ('pork', 16410),
#  ('sage', 16351),
#  ('hamburger', 16264),
#  ('lime', 16198),
#  ('chunk', 16184),
#  ('cooking spray', 16053),
#  ('swiss cheese', 15482),
#  ('chocolate', 15445),
#  ('tabasco', 15354),
#  ('maple syrup', 15227),
#  ('black bean', 15207),
#  ('yellow cake mix', 15141),
#  ('pineapple juice', 15017),
#  ('cherry tomato', 15012),
#  ('yogurt', 14996),
#  ('monterey jack cheese', 14972),
#  ('wine vinegar', 14880),
#  ('wedge', 14543),
#  ('cream tartar', 14502),
#  ('celery seed', 14380),
#  ('raspberry', 14348),
#  ('olive', 14338),
#  ('breadcrumb', 14274),
#  ('cooking oil', 14161),
#  ('sweetened condensed milk', 14156),
#  ('chicken breast half', 14103),
#  ('lowfat milk', 14088),
#  ('flour tortilla', 13859),
#  ('italian seasoning', 13758),
#  ('salsa', 13731),
#  ('kidney bean', 13676),
#  ('catsup', 13555),
#  ('purpose flour', 13308),
#  ('peanut', 13207),
#  ('cake flour', 13119),
#  ('dark brown sugar', 12767),
#  ('yeast', 12699),
#  ('sausage', 12610),
#  ('beef broth', 12570),
#  ('coconut milk', 12506),
#  ('orange', 12360),
#  ('graham cracker crumb', 12316),
#  ('velveeta cheese', 12175),
#  ('cottage cheese', 12138),
#  ('fine', 12105),
#  ('skim milk', 12048),
#  ('apricot', 11971),
#  ('whipped cream', 11738),
#  ('unsweetened cocoa', 11641),
#  ('date', 11609),
#  ('active dry yeast', 11428),
#  ('cherry', 11421),
#  ('tomato soup', 11395),
#  ('pasta', 11252),
#  ('cayenne', 11222),
#  ('kernel corn', 11184),
#  ('pure vanilla extract', 11166),
#  ('flatleaf parsley', 11093),
#  ('cornmeal', 11078),
#  ('miniature marshmallow', 11051),
#  ('pine nut', 11037),
#  ('avocado', 11019),
#  ('tarragon', 11018),
#  ('parsley flake', 11012),
#  ('crisco', 10882),
#  ('apple cider vinegar', 10866),
#  ('sweet onion', 10839),
#  ('rolled oat', 10751),
#  ('ice', 10689),
#  ('fish', 10625),
#  ('salt pepper', 10337),
#  ('dill weed', 10249),
#  ('red wine', 10248),
#  ('plum tomato', 10200),
#  ('heart', 10194),
#  ('mushroom soup', 10067),
#  ('eggplant', 10060),
#  ('baby spinach', 10054),
#  ('cream celery soup', 10045),
#  ('vanilla ice cream', 10031),
#  ('skin', 10028),
#  ('water chestnut', 9966),
#  ('salad', 9960),
#  ('tuna', 9937),
#  ('peanut oil', 9881),
#  ('ricotta cheese', 9876),
#  ('hardboiled egg', 9846),
#  ('caper', 9803),
#  ('corn tortilla', 9667),
#  ('coarse salt', 9608),
#  ('floret', 9545),
#  ('bean', 9526),
#  ('maraschino cherry', 9501),
#  ('ice cube', 9482),
#  ('parmesan', 9478),
#  ('crust', 9436),
#  ('oats', 9413),
#  ('marshmallow', 9378),
#  ('chicken thigh', 9321),
#  ('rice vinegar', 9299),
#  ('seed', 9248),
#  ('juice lemon', 9239),
#  ('cherry pie', 9214),
#  ('red potato', 9212),
#  ('dice', 9075),
#  ('allspice', 9039),
#  ('pimento', 9009),
#  ('recipe', 8883),
#  ('vegetable stock', 8880),
#  ('liquid', 8827),
#  ('pork chop', 8763),
#  ('feta cheese', 8660),
#  ('cumin seed', 8651),
#  ('jalapeno', 8636),
#  ('rum', 8616),
#  ('meat', 8506),
#  ('applesauce', 8483),
#  ('tomato juice', 8479),
#  ('celery rib', 8479),
#  ('salmon', 8440),
#  ('seasoned salt', 8400),
#  ('stewed tomato', 8336),
#  ('poppy seed', 8180),
#  ('american cheese', 8164),
#  ('marjoram', 8159),
#  ('mustard seed', 8112),
#  ('leave', 8069),
#  ('dry yeast', 8066),
#  ('beer', 8038),
#  ('semisweet chocolate', 7985),
#  ('vegetable broth', 7981),
#  ('fruit', 7958),
#  ('black peppercorn', 7857),
#  ('vegetable', 7849),
#  ('bisquick', 7824),
#  ('lemon peel', 7775),
#  ('apple juice', 7724),
#  ('brandy', 7692),
#  ('crosswise', 7676),
#  ('bread flour', 7667),
#  ('whipped', 7628),
#  ('basil leave', 7617),
#  ('mango', 7596),
#  ('lemon rind', 7586),
#  ('dry sherry', 7574),
#  ('macaroni', 7565),
#  ('chickpea', 7513),
#  ('barbecue', 7477),
#  ('celery salt', 7422),
#  ('mashed banana', 7351),
#  ('taco seasoning', 7318),
#  ('syrup', 7290),
#  ('cilantro leave', 7282),
#  ('eagle brand milk', 7249),
#  ('noodle', 7238),
#  ('ritz cracker', 7225),
#  ('cake', 7199),
#  ('choice', 7161),
#  ('mixed vegetable', 7111),
#  ('pie crust', 7105),
#  ('pinto bean', 7056),
#  ('cake mix', 7046),
#  ('philadelphia cream cheese', 7009),
#  ('tortilla chip', 6998),
#  ('canned tomato', 6963),
#  ('graham cracker', 6939),
#  ('miracle whip', 6901),
#  ('cauliflower', 6870),
#  ('pecan half', 6854),
#  ('creamy peanut butter', 6845),
#  ('dry red wine', 6842),
#  ('ginger ale', 6820),
#  ('ring', 6798),
#  ('pear', 6722),
#  ('cardamom', 6695),
#  ('instant vanilla pudding', 6678),
#  ('mandarin orange', 6578),
#  ('vodka', 6556),
#  ('golden raisin', 6531),
#  ('sharp cheese', 6499),
#  ('oyster', 6495),
#  ('fennel seed', 6460),
#  ('lengthwise', 6410),
#  ('salmon fillet', 6396),
#  ('creamstyle corn', 6392),
#  ('freshly parmesan cheese', 6372),
#  ('vanilla wafer', 6357),
#  ('corn kernel', 6286),
#  ('herb', 6265),
#  ('uncooked rice', 6248),
#  ('asparagus', 6246),
#  ('pumpkin', 6206),
#  ('kraft', 6194),
#  ('italian parsley', 6183),
#  ('pork tenderloin', 6155),
#  ('goat cheese', 6154),
#  ('beef stock', 6151),
#  ('vanilla bean', 6149),
#  ('loaf', 6129),
#  ('gelatin', 6116),
#  ('sundried tomato', 6111),
#  ('pumpkin pie spice', 6083),
#  ('russet potato', 6069),
#  ('coconut oil', 6049),
#  ('rhubarb', 6001),
#  ('mozzarella', 5920),
#  ('caster sugar', 5909),
#  ('dry bread crumb', 5886),
#  ('spring onion', 5884),
#  ('apple cider', 5838),
#  ('egg noodle', 5804),
#  ('corn flake', 5804),
#  ('pan', 5785),
#  ('jalapenos', 5768),
#  ('greek yogurt', 5691),
#  ('brown rice', 5681),
#  ('orange peel', 5679),
#  ('sweet red pepper', 5653),
#  ('caraway seed', 5649),
#  ('roma tomato', 5617),
#  ('caramel', 5608),
#  ('italian sausage', 5608),
#  ('carton sour cream', 5570),
#  ('yellow squash', 5569),
#  ('rice krispie', 5565),
#  ('orange rind', 5563),
#  ('refried bean', 5531),
#  ('ice water', 5514),
#  ('poultry seasoning', 5505),
#  ('adobo', 5477),
#  ('radish', 5462),
#  ('rotel tomato', 5375),
#  ('freshly nutmeg', 5371),
#  ('pork bean', 5367),
#  ('crescent roll', 5351),
#  ('graham cracker crust', 5345),
#  ('red kidney bean', 5340),
#  ('button mushroom', 5331),
#  ('beet', 5315),
#  ('red food coloring', 5307),
#  ('onion soup mix', 5304),
#  ('lemon wedge', 5270),
#  ('bean sprout', 5260),
#  ('cracker crumb', 5259),
#  ('mandarin', 5256),
#  ('chicken bouillon cube', 5245),
#  ('unbaked pie shell', 5245),
#  ('elbow', 5236),
#  ('green pea', 5232),
#  ('mix', 5231),
#  ('coriander seed', 5225),
#  ('pastry', 5217),
#  ('liquid smoke', 5214),
#  ('cheddar', 5203),
#  ('condensed milk', 5189),
#  ('carton cool whip', 5126),
#  ('creme fraiche', 5113),
#  ('bourbon', 5089),
#  ('vegetable shortening', 5078),
#  ('green olive', 5061),
#  ('yellow cornmeal', 5061),
#  ('mirin', 5056),
#  ('lemon extract', 5055),
#  ('tomato puree', 5048),
#  ('yellow bell pepper', 5036),
#  ('mashed potato', 5030),
#  ('blue cheese', 5015),
#  ('blackberry', 5007),
#  ('lamb', 5001),
#  ('round steak', 4984),
#  ('unflavored gelatin', 4953),
#  ('crumbled feta cheese', 4940),
#  ('cashew', 4901),
#  ('lime wedge', 4851),
#  ('roasted red pepper', 4848),
#  ('gingerroot', 4842),
#  ('kale', 4834),
#  ('flat leaf parsley', 4828),
#  ('karo syrup', 4827),
#  ('grape tomato', 4825),
#  ('sherry', 4803),
#  ('hash brown', 4790),
#  ('onion salt', 4787),
#  ('instant pudding', 4744),
#  ('pie shell', 4736),
#  ('prepared horseradish', 4713),
#  ('pizza', 4712),
#  ('garam masala', 4691),
#  ('hazelnut', 4681),
#  ('unsweetened chocolate', 4679),
#  ('dark chocolate', 4666),
#  ('prosciutto', 4663),
#  ('long grain rice', 4660),
#  ('sake', 4652),
#  ('corn meal', 4651),
#  ('bitesize', 4634),
#  ('granny smith apple', 4616),
#  ('pineapple chunk', 4549),
#  ('taco seasoning mix', 4543),
#  ('quarter', 4539),
#  ('drizzling', 4533),
#  ('pie', 4516),
#  ('bittersweet chocolate', 4514),
#  ('lemonade', 4512),
#  ('sunflower seed', 4493),
#  ('arugula', 4478),
#  ('rice wine vinegar', 4471),
#  ('kalamata olive', 4459),
#  ('hamburger bun', 4453),
#  ('canned pumpkin', 4443),
#  ('lukewarm water', 4406),
#  ('butternut squash', 4402),
#  ('peppercorn', 4397),
#  ('green chile', 4396),
#  ('romano cheese', 4384),
#  ('fruit cocktail', 4379),
#  ('currant', 4378),
#  ('jello', 4377),
#  ('baby carrot', 4375),
#  ('yukon gold potato', 4367),
#  ('chicken wing', 4348),
#  ('lemon jello', 4329),
#  ('dark rum', 4317),
#  ('ingredient', 4293),
#  ('pretzel', 4292),
#  ('wesson oil', 4286),
#  ('hardcooked egg', 4286),
#  ('egg substitute', 4275),
#  ('fennel bulb', 4246),
#  ('butterscotch chip', 4244),
#  ('beef bouillon cube', 4240),
#  ('corn oil', 4235),
#  ('pimiento', 4231),
#  ('hoisin', 4230),
#  ('cheez whiz', 4221),
#  ('pistachio', 4196),
#  ('oreo cookie', 4179),
#  ('boiled egg', 4171),
#  ('bone', 4160),
#  ('biscuit', 4159),
#  ('lowfat sour cream', 4146),
#  ('oregano leave', 4145),
#  ('pwdr', 4106),
#  ('parsnip', 4090),
#  ('square', 4086),
#  ('rind', 4077),
#  ('stew meat', 4073),
#  ('orange juice concentrate', 4064),
#  ('minute rice', 4037),
#  ('lasagna noodle', 4029),
#  ('slivered almond', 4027),
#  ('lard', 4006),
#  ('onion flake', 3989),
#  ('steak', 3977),
#  ('provolone cheese', 3976),
#  ('unsweetened applesauce', 3971),
#  ('t', 3961),
#  ('broccoli floret', 3949),
#  ('yellow mustard', 3931),
#  ('snow pea', 3929),
#  ('mini marshmallow', 3921),
#  ('mayo', 3898),
#  ('cannellini bean', 3881),
#  ('cracker', 3872),
#  ('ear', 3852),
#  ('unbleached allpurpose flour', 3848),
#  ('okra', 3846),
#  ('lemon pepper', 3829),
#  ('wheat germ', 3829),
#  ('garbanzo bean', 3828),
#  ('french bread', 3819),
#  ('red cabbage', 3811),
#  ('fine sea salt', 3810),
#  ('orange jello', 3788),
#  ('fig', 3786),
#  ('sweet milk', 3775),
#  ('lima bean', 3775),
#  ('crab meat', 3771),
#  ('minute', 3761),
#  ('dough', 3753),
#  ('italian dressing', 3736),
#  ('potato chip', 3734),
#  ('red chili', 3700),
#  ('gruyere cheese', 3700),
#  ('pancetta', 3687),
#  ('pork sausage', 3683),
#  ('green cabbage', 3682),
#  ('chocolate syrup', 3678),
#  ('butter oleo', 3669),
#  ('quick oat', 3651),
#  ('linguine', 3649),
#  ('peeled ginger', 3631),
#  ('inchthick', 3630),
#  ('sprig', 3628),
#  ('lowfat yogurt', 3627),
#  ('thyme sprig', 3621),
#  ('broth', 3569),
#  ('condensed cream mushroom soup', 3566),
#  ('wild rice', 3550),
#  ('salted butter', 3545),
#  ('parmigianoreggiano cheese', 3535),
#  ('length', 3514),
#  ('cranberry juice', 3513),
#  ('shell', 3504),
#  ('instant coffee', 3502),
#  ('sherry vinegar', 3491),
#  ('partskim mozzarella cheese', 3478),
#  ('new potato', 3470),
#  ('king sooper', 3455),
#  ('pepperoni', 3449),
#  ('orange marmalade', 3447),
#  ('firm tofu', 3433),
#  ('low sodium chicken broth', 3429),
#  ('ginger root', 3418),
#  ('med onion', 3418),
#  ('pure maple syrup', 3416),
#  ('stem', 3412),
#  ('nonfat yogurt', 3406),
#  ('chili pepper', 3398),
#  ('lentil', 3395),
#  ('round', 3393),
#  ('tart apple', 3391),
#  ('crumb', 3390),
#  ('ice cream', 3384),
#  ('dry onion soup mix', 3379),
#  ('iceberg lettuce', 3360),
#  ('turnip', 3346),
#  ('sour milk', 3330),
#  ('coffee', 3322),
#  ('sheet', 3319),
#  ('x egg', 3310),
#  ('milk chocolate chip', 3307),
#  ('table salt', 3299),
#  ('taco', 3295),
#  ('pineapple tidbit', 3246),
#  ('direction', 3232),
#  ('cajun seasoning', 3232),
#  ('watercress', 3196),
#  ('turkey breast', 3184),
#  ('green part', 3177),
#  ('club soda', 3171),
#  ('sauerkraut', 3171),
#  ('unbleached flour', 3153),
#  ('stock', 3153),
#  ('fat', 3138),
#  ('sweet paprika', 3136),
#  ('crouton', 3127),
#  ('sriracha', 3109),
#  ('bacon bit', 3081),
#  ('green', 3079),
#  ('distilled vinegar', 3071),
#  ('flank steak', 3051),
#  ('penne pasta', 3051),
#  ('baguette', 3046),
#  ('arborio rice', 3044),
#  ('x salt', 3042),
#  ('picante', 3023),
#  ('yellow pepper', 3022),
#  ('english cucumber', 3014),
#  ('envelope', 3011),
#  ('anchovy fillet', 2997),
#  ('hash brown potato', 2990),
#  ('flax seed', 2985),
#  ('agave nectar', 2975),
#  ('zest lemon', 2974),
#  ('angel food cake', 2956),
#  ('vegetable cooking spray', 2949),
#  ('marshmallow cream', 2948),
#  ('lime jello', 2946),
#  ('ribs celery', 2946),
#  ('great northern bean', 2940),
#  ('crumbled blue cheese', 2936),
#  ('prune', 2930),
#  ('weight cream cheese', 2926),
#  ('tequila', 2925),
#  ('dashes', 2921),
#  ('x garlic', 2921),
#  ('rosemary leave', 2918),
#  ('reducedsodium chicken broth', 2915),
#  ('vidalia onion', 2914),
#  ('peeled tomato', 2912),
#  ('grape', 2905),
#  ('blanched almond', 2903),
#  ('german chocolate cake mix', 2900),
#  ('basmati rice', 2893),
#  ('chilie', 2874),
#  ('spanish onion', 2874),
#  ('food coloring', 2868),
#  ('weight', 2862),
#  ('wheat bread', 2858),
#  ('top', 2854),
#  ('chile', 2854),
#  ('hamburger meat', 2852),
#  ('plum', 2837),
#  ('coarse black pepper', 2825),
#  ('red chili pepper', 2820),
#  ('dark corn syrup', 2819),
#  ('superfine sugar', 2817),
#  ('corn chip', 2816),
#  ('seasoning', 2815),
#  ('smoked sausage', 2811),
#  ('condensed cream chicken soup', 2809),
#  ('nonstick cooking spray', 2778),
#  ('chocolate cake mix', 2776),
#  ('berry', 2775),
#  ('fatfree milk', 2774),
#  ('dill pickle', 2768),
#  ('old bay seasoning', 2765),
#  ('enchilada', 2760),
#  ('green tomato', 2760),
#  ('veal', 2746),
#  ('english muffin', 2736),
#  ('marshmallow creme', 2735),
#  ('thyme leave', 2732),
#  ('chow mein noodle', 2731),
#  ('pork shoulder', 2727),
#  ('sunflower oil', 2726),
#  ('rice flour', 2726),
#  ('granny smith apples', 2725),
#  ('pesto', 2722),
#  ('marinara', 2720),
#  ('lowsodium chicken broth', 2718),
#  ('mexican cheese', 2715),
#  ('parsley leave', 2713),
#  ('simple syrup', 2706),
#  ('cremini mushroom', 2706),
#  ('crunchy peanut butter', 2698),
#  ('chipotle chile', 2698),
#  ('baked pie shell', 2693),
#  ('saltine cracker', 2673),
#  ('mint leave', 2654),
#  ('tortillas', 2635),
#  ('leeks', 2633),
#  ('mashed sweet potato', 2632),
#  ('spice', 2630),
#  ('mild cheddar cheese', 2626),
#  ('mint sprig', 2624),
#  ('butter room temperature', 2623),
#  ('fish fillet', 2622),
#  ('sm', 2619),
#  ('cookie', 2617),
#  ('mascarpone cheese', 2616),
#  ('star anise', 2616),
#  ('cheddar cheese soup', 2611),
#  ('green food coloring', 2609),
#  ('hershey', 2603),
#  ('loaf french bread', 2601),
#  ('dream whip', 2601),
#  ('safeway', 2599),
#  ('granulated garlic', 2585),
#  ('marinade', 2573),
#  ('casing', 2564),
#  ('pitted date', 2559),
#  ('juice lime', 2558),
#  ('nonfat milk', 2543),
#  ('chili bean', 2540),
#  ('fryer', 2540),
#  ('saffron', 2539),
#  ('mussel', 2539),
#  ('corned beef', 2535),
#  ('candied cherry', 2535),
#  ('velveeta', 2533),
#  ('asparagus spear', 2530),
#  ('rotel', 2528),
#  ('panko breadcrumb', 2527),
#  ('dog', 2518),
#  ('saffron thread', 2511),
#  ('freshly', 2495),
#  ('teriyaki', 2493),
#  ('pet milk', 2491),
#  ('dry breadcrumb', 2481),
#  ('cornflake', 2479),
#  ('t salt', 2476),
#  ('baby', 2476),
#  ('macadamia nut', 2474),
#  ('cool whip whipped', 2472),
#  ('sherry wine', 2462),
#  ('milk chocolate', 2461),
#  ('celery ribs', 2447),
#  ('low sodium soy', 2438),
#  ('stuffing mix', 2432),
#  ('coarse sea salt', 2430),
#  ('rib', 2425),
#  ('sweet pickle relish', 2418),
#  ('almond milk', 2414),
#  ('peeled apple', 2394),
#  ('crisco oil', 2393),
#  ('vanilla pudding', 2390),
#  ('tbs', 2386),
#  ('ranch dressing', 2385),
#  ('sirloin', 2379),
#  ('pumpkin seed', 2378),
#  ('almond flour', 2377),
#  ('lemongrass', 2376),
#  ('grapeseed oil', 2374),
#  ('bacon dripping', 2370),
#  ('wheat pastry flour', 2364),
#  ('pecans', 2360),
#  ('pork loin', 2360),
#  ('sea scallop', 2356),
#  ('confectioners sugar', 2355),
#  ('scallop', 2350),
#  ('green chili pepper', 2347),
#  ('fennel', 2341),
#  ('parsley sprig', 2331),
#  ('powdered milk', 2321),
#  ('instant onion', 2315),
#  ('clams', 2308),
#  ('italian salad', 2308),
#  ('land o', 2295),
#  ('dressing', 2294),
#  ('grand marnier', 2280),
#  ('tail', 2272),
#  ('leek', 2266),
#  ('tofu', 2262),
#  ('instant vanilla pudding mix', 2252),
#  ('butter bean', 2251),
#  ('splenda sugar substitute', 2251),
#  ('cognac', 2249),
#  ('karo', 2237),
#  ('baking potato', 2228),
#  ('fettuccine', 2212),
#  ('pizza dough', 2210),
#  ('instant rice', 2206),
#  ('soup', 2202),
#  ('old fashioned oat', 2202),
#  ('hellmanns mayonnaise', 2188),
#  ('vanilla essence', 2180),
#  ('cherry jello', 2176),
#  ('sugar snap pea', 2173),
#  ('unsifted flour', 2171),
#  ('sq unsweetened chocolate', 2164),
#  ('longgrain rice', 2164),
#  ('kahlua', 2161),
#  ('chipotle pepper', 2155),
#  ('graham cracker pie crust', 2151),
#  ('nonfat dry milk', 2142),
#  ('packet', 2140),
#  ('navy bean', 2140),
#  ('chicken bouillon', 2138),
#  ('dark sesame oil', 2135),
#  ('lowsodium soy', 2134),
#  ('planter', 2133),
#  ('dipping', 2126),
#  ('soymilk', 2125),
#  ('green chili', 2124),
#  ('zest', 2118),
#  ('brussels sprout', 2113),
#  ('breakstone', 2113),
#  ('lipton onion soup mix', 2108),
#  ('puff pastry', 2106),
#  ('cornflour', 2106),
#  ('canola', 2099),
#  ('cantaloupe', 2096),
#  ('squash', 2093),
#  ('grain mustard', 2093),
#  ('sharp cheddar', 2086),
#  ('food cake mix', 2085),
#  ('english pea', 2075),
#  ('mini chocolate chip', 2065),
#  ('flavor', 2061),
#  ('peppermint extract', 2052),
#  ('dairy sour cream', 2051),
#  ('tub cool whip', 2050),
#  ('gin', 2049),
#  ('biscuit mix', 2040),
#  ('condensed tomato soup', 2037),
#  ('angel hair pasta', 2031),
#  ('virgin', 2031),
#  ('purple onion', 2030),
#  ('lemonade concentrate', 2028),
#  ('beef brisket', 2026),
#  ('artichoke', 2020),
#  ('creole seasoning', 2019),
#  ('tapioca', 2016),
#  ('crystallized ginger', 2015),
#  ('sirloin steak', 2015),
#  ('semisweet chocolate morsel', 2014),
#  ('peel', 2014),
#  ('barley', 2011),
#  ('pudding', 2005),
#  ('eagle brand', 2003),
#  ('roasted peanut', 2003),
#  ('pc', 1984),
#  ('salami', 1983),
#  ('roast', 1981),
#  ('toasted almond', 1977),
#  ('bakers semisweet chocolate', 1976),
#  ('napa cabbage', 1975),
#  ('rosemary sprig', 1971),
#  ('red chile', 1969),
#  ('dry vermouth', 1966),
#  ('roll', 1961),
#  ('chip', 1958),
#  ('instant chocolate pudding', 1954),
#  ('tbs olive oil', 1951),
#  ('reducedsodium soy', 1945),
#  ('shiitake mushroom', 1945),
#  ('apricot jam', 1943),
#  ('oscar mayer', 1943),
#  ('vanilla yogurt', 1941),
#  ('tater tot', 1937),
#  ('panko bread crumb', 1934),
#  ('pickling spice', 1932),
#  ('tea', 1930),
#  ('peanut butter chip', 1926),
#  ('chuck roast', 1921),
#  ('clam juice', 1920),
#  ('room temp', 1920),
#  ('cob', 1916),
#  ('bread dough', 1909),
#  ('seedless raisin', 1908),
#  ('asiago cheese', 1908),
#  ('beef bouillon', 1907),
#  ('italian bread', 1905),
#  ('penne', 1901),
#  ('red chilie', 1898),
#  ('whip', 1896),
#  ('pearl onion', 1895),
#  ('chipotle', 1892),
#  ('unsweetened pineapple juice', 1890),
#  ('cardamom pod', 1890),
#  ('guacamole', 1887),
#  ('pillsbury', 1885),
#  ('salt freshly black pepper', 1878),
#  ('horseradish', 1873),
#  ('matchstick', 1873),
#  ('corn starch', 1871),
#  ('quick cooking oat', 1867),
#  ('brushing', 1864),
#  ('chunky peanut butter', 1857),
#  ('grnd beef', 1854),
#  ('tomatillos', 1849),
#  ('miso', 1847),
#  ('triple sec', 1844),
#  ('poblano pepper', 1844),
#  ('beef chuck', 1839),
#  ('walnut half', 1835),
#  ('frenchstyle green bean', 1830),
#  ('orange liqueur', 1828),
#  ('pickle', 1828),
#  ('lump crabmeat', 1814),
#  ('instant coffee granule', 1799),
#  ('curd cottage cheese', 1796),
#  ('pinche', 1793),
#  ('salt pork', 1791),
#  ('xanthan gum', 1790),
#  ('eagle brand sweetened condensed milk', 1783),
#  ('bowl', 1783),
#  ('port', 1780),
#  ('lg onion', 1779),
#  ('baked bean', 1775),
#  ('smooth peanut butter', 1775),
#  ('jam', 1774),
#  ('freshly squeezed lime juice', 1774),
#  ('red bean', 1762),
#  ('garlic pwdr', 1761),
#  ('seedless grape', 1760),
#  ('uncooked shrimp', 1759),
#  ('lowfat buttermilk', 1757),
#  ('double cream', 1753),
#  ('sweet pickle', 1752),
#  ('jack cheese', 1745),
#  ('watermelon', 1741),
#  ('quinoa', 1740),
#  ('bulk pork sausage', 1738),
#  ('instant yeast', 1737),
#  ('feta', 1737),
#  ('french fried onion', 1731),
#  ('rubbed sage', 1727),
#  ('lemon flavoring', 1723),
#  ('use', 1721),
#  ('chunk pineapple', 1716),
#  ('chia seed', 1706),
#  ('fine dry bread crumb', 1701),
#  ('monterey jack', 1693),
#  ('scalded milk', 1693),
#  ('apple pie', 1686),
#  ('meatball', 1686),
#  ('strong coffee', 1682),
#  ('sourdough bread', 1680),
#  ('pearl barley', 1678),
#  ('venison', 1678),
#  ('soy milk', 1676),
#  ('anchovy', 1675),
#  ('blueberry pie', 1674),
#  ('fontina cheese', 1670),
#  ('x sugar', 1669),
#  ('third', 1667),
#  ('floweret', 1663),
#  ('carton whipped', 1662),
#  ('mixed salad green', 1662),
#  ('chicken leg', 1661),
#  ('coconut extract', 1659),
#  ('tube', 1659),
#  ('dry roasted peanut', 1653),
#  ('chili flake', 1653),
#  ('sprig thyme', 1651),
#  ('lowfat', 1650),
#  ('fully ham', 1649),
#  ('thin wedge', 1648),
#  ('pita bread', 1648),
#  ('chop', 1646),
#  ('crusty bread', 1646),
#  ('split', 1642),
#  ('fine salt', 1637),
#  ('grain', 1626),
#  ('red apple', 1620),
#  ('roasted garlic', 1619),
#  ('ham hock', 1616),
#  ('champagne', 1616),
#  ('sweet pepper', 1613),
#  ('bisquick baking mix', 1613),
#  ('instant espresso', 1608),
#  ('nutritional yeast', 1602),
#  ('dill seed', 1601),
#  ('hamburg', 1600),
#  ('candied pineapple', 1596),
#  ('vegall', 1595),
#  ('bamboo shoot', 1594),
#  ('bok choy', 1593),
#  ('decoration', 1592),
#  ('leg lamb', 1590),
#  ('grape juice', 1588),
#  ('cinnamon sugar', 1588),
#  ('instant chocolate pudding mix', 1584),
#  ('dark chocolate chip', 1583),
#  ('sweet italian sausage', 1581),
#  ('peeled potato', 1580),
#  ('lemon cake mix', 1578),
#  ('cracked pepper', 1578),
#  ('unbaked pie crust', 1577),
#  ('chorizo sausage', 1576),
#  ('wide egg noodle', 1575),
#  ('sweet corn', 1574),
#  ('turbinado sugar', 1574),
#  ('espresso', 1573),
#  ('hominy', 1571),
#  ('plus virgin olive oil', 1571),
#  ('dark soy', 1570),
#  ('rice wine', 1570),
#  ('sweet basil', 1569),
#  ('basil leaf', 1569),
#  ...]

# %%
# Save to a text file, one ingredient per line
ingredients_only = [item for item, count in filtered]
with open("spacy_unique_ingredients.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(ingredients_only))

print(f"Saved {len(ingredients_only)} unique ingredients to unique_ingredients.txt")
# Out:
# Saved 1036 unique ingredients to unique_ingredients.txt

# %% [markdown]
# ## Calculate rought number of tokens of ingredients

# %%
import spacy

# Read ingredients from file
with open("spacy_unique_ingredients.txt", "r", encoding="utf-8") as f:
    unique_ingredients = [line.strip() for line in f if line.strip()]
# Load spaCy model
nlp = spacy.load(
    "en_core_web_sm",
    disable=["parser", "ner", "tagger", "lemmatizer", "attribute_ruler", "morphologizer"],
)
# Count tokens
total_tokens = 0
for doc in nlp.pipe(unique_ingredients, batch_size=1000):
    total_tokens += len(doc)
print(f"Approximate total token count: {total_tokens:,}")
# Out:
# Approximate total token count: 1,855
