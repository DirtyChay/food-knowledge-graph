# %%
from dotenv import load_dotenv

load_dotenv()  # Take environment variables from .env
import pandas as pd
import json
from openai import OpenAI
import os

with open("SpacyProcessing/spacy_unique_ingredients.txt", "r", encoding="utf-8") as f:
    UNIQUE_INGREDIENTS = f.read()

with open("prompts/system_message_products.txt", "r", encoding="utf-8") as f:
    SYSTEM_MSG_PRODUCTS = f.read()
    SYSTEM_MSG_PRODUCTS += UNIQUE_INGREDIENTS

# %%
# CONFIGURATION
INPUT_CSV = "data/raw/usda_2022_food_branded_experimental_DESCRIPTION_ONLY.csv"  # Your source file
BATCH_FILE_NAME = "batch_input.jsonl"  # The file we will send to OpenAI
MODEL_NAME = "gpt-5-nano-2025-08-07"  # <--- UPDATED MODEL
API_KEY = os.getenv("OPENAI_API_KEY")  # Ensure your env var is set

# Initialize Client
client = OpenAI(api_key=API_KEY)

# 1. Load your data
print(f"Loading data from {INPUT_CSV}...")
df = pd.read_csv(INPUT_CSV)
df.head(3)
# Out:
# Loading data from data/raw/usda_2022_food_branded_experimental_DESCRIPTION_ONLY.csv...
#    fdc_id                                        description
# 0  167512  Pillsbury Golden Layer Buttermilk Biscuits, Ar...
# 1  167513  Pillsbury, Cinnamon Rolls with Icing, refriger...
# 2  167514  Kraft Foods, Shake N Bake Original Recipe, Coa...

# %%
print(SYSTEM_MSG_PRODUCTS)
# Out:
# You are a culinary data annotator.
# Your job is to map a retail food product name to exactly one canonical ingredient label.
#
# Return **only** a plain lowercase string — no JSON, no lists, no quotes, no commentary.
#
# ---
#
# # TASK
# Given a product name from a grocery or restaurant context, output the **single best ingredient label** it represents.
#
# Use the ALLOWED_INGREDIENTS list as your **reference vocabulary**, **not a restriction**.
# These ingredients are *examples* drawn from a prior extraction process.
# If none match well, you may output **any realistic ingredient name**, even if it is not in ALLOWED_INGREDIENTS.
#
# ---
#
# # RULES (perform mentally)
#
# ## 1. Normalize text
# Lowercase everything; remove punctuation, symbols, brand names, marketing language (organic, classic, premium), sizes/quantities (oz, pack, 12-ct), and prep descriptors (sliced, shredded, spicy).
# Preserve identity-defining terms (olive oil, soy sauce, apple cider vinegar, taco seasoning, pudding mix).
#
# ## 2. Remove usage phrases
# Drop “for X”, “with X”, “on X”.
# Interpret only the ingredient identity, not the intended use.
#
# ## 3. Ignore packaging
# Ignore container words (bottle, jar, pack, frozen, canned) unless part of a canonical identity (e.g., taco seasoning, cake mix, pudding mix, salad dressing).
#
# ## 4. Match to ALLOWED_INGREDIENTS
# Choose the most specific valid match.
# If multiple matches, pick the one that captures the core ingredient identity.
# If none match closely, **create a new ingredient label** that best reflects the product’s true food identity.
#
# ## 5. Inference
# Infer identities only when overwhelmingly clear:
# - soda → baking soda
# - pepper (spice/seasoning context) → black pepper
# Preserve identity-defining flavors/types (barbecue sauce, ranch seasoning, chocolate pudding mix).
#
# ## 6. Singularization
# Normalize to singular unless the plural is canonical.
# Do not modify true multi-word identities (ground beef, pork shoulder, chocolate pudding mix).
#
# ## 7. If no allowed ingredient fits
# Produce a short, real ingredient name (e.g., pea protein, gochujang, tamarind paste).
# Do **not** return a dish name.
#
# ## 8. Output format
# Return exactly one plain lowercase ingredient label.
# No punctuation, commas, conjunctions, or explanations.
#
# ---
#
# # SPECIAL LOGIC
#
# ### Animal proteins
# Keep meat cuts (ground beef, chicken breast).
# Collapse seafood cuts (salmon fillet → salmon).
# Keep processed meats distinct (bacon, sausage, ham, pepperoni).
#
# ### Tomato products
# Keep explicit items (tomato paste, tomato sauce).
# Whole/diced/etc. → tomato.
#
# ### Oils
# Keep explicit oil types.
# Generic → oil.
#
# ### Mint
# Herb → mint.
# Candy → chocolate mint candy.
#
# ### Mixes
# Keep canonical identities (devils food cake mix, chocolate pudding mix, taco seasoning).
#
# ### Seasonings / coatings
# coating, breading, batter → breadcrumb or batter mix
# seasoning/spice mix → appropriate seasoning label
#
# ### Produce peppers
# bell pepper, jalapeño, etc. remain produce.
#
# ---
#
# # EXAMPLES
# kraft shake ’n bake original recipe coating for pork → breadcrumb
# mccormick taco seasoning mix → taco seasoning
# tempura batter mix for shrimp → batter mix
# barilla spaghetti no. 5 → spaghetti
# la croix lime sparkling water → water
# restaurant arroz con habichuelas colorados → red bean
# gochujang hot pepper paste → gochujang
#
# ---
#
# ALLOWED_INGREDIENTS:
# salt
# sugar
# egg
# onion
# butter
# garlic
# water
# pepper
# flour
# milk
# olive oil
# vanilla
# brown sugar
# cinnamon
# tomato
# soda
# lemon juice
# black pepper
# allpurpose flour
# margarine
# carrot
# cream cheese
# sour cream
# celery
# parsley
# oil
# vegetable oil
# beef
# vanilla extract
# green onion
# parmesan cheese
# mayonnaise
# pecan
# cheddar cheese
# unsalted butter
# mushroom
# cream
# nutmeg
# kosher salt
# vinegar
# green pepper
# ginger
# nut
# basil
# honey
# virgin olive oil
# potato
# oregano
# chicken breast
# worcestershire
# thyme
# soy
# paprika
# cornstarch
# powdered sugar
# cumin
# chicken
# bacon
# chili
# pineapple
# chicken broth
# walnut
# granulated sugar
# shortening
# red onion
# freshly black pepper
# raisin
# egg yolk
# cilantro
# buttermilk
# lemon
# rice
# orange juice
# red pepper
# cocoa
# cheese
# banana
# lime juice
# cayenne pepper
# strawberry
# butter margarine
# apple
# broccoli
# cream mushroom soup
# mozzarella cheese
# almond
# juice
# mustard
# zucchini
# whipping cream
# dijon mustard
# cream chicken soup
# cool whip
# egg white
# canola oil
# spinach
# confectioner
# tomato paste
# cube
# scallion
# room temperature
# chocolate chip
# red bell pepper

# %%
# 2. Define your System Prompt (Paste your long >1024 token prompt here)
# Since you mentioned your prompt is long, just paste it entirely below.
system_prompt = """
You are a specialized food database assistant.
[...PASTE YOUR FULL 1024+ TOKEN PROMPT HERE...]
Your task is to extract the simple, generic food type from the description.
Remove brand names, quantities, and packaging details.
Return ONLY the lowercase food type.
"""

# 3. Prepare the Batch Requests
batch_requests = []

print("Preparing batch requests...")
for index, row in df.iterrows():
    # We use fdc_id as the custom_id to map it back later
    custom_id = str(row['fdc_id'])

    request_body = {
        "custom_id": custom_id,
        "method": "POST",
        "url": "/v1/chat/completions",
        "body": {
            "model": MODEL_NAME,  # Using gpt-5-nano-2025-08-07
            "messages": [
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": row['description']}
            ],
            "max_tokens": 50,  # Keep this low for simple extraction to save money
            "temperature": 0
        }
    }
    batch_requests.append(request_body)

# 4. Save to JSONL
with open(BATCH_FILE_NAME, "w") as f:
    for req in batch_requests:
        f.write(json.dumps(req) + "\n")

print(f"Saved {len(batch_requests)} requests to {BATCH_FILE_NAME}")

# 5. Upload File to OpenAI
print("Uploading file to OpenAI...")
batch_file = client.files.create(
    file=open(BATCH_FILE_NAME, "rb"),
    purpose="batch"
)
print(f"File uploaded. File ID: {batch_file.id}")

# 6. Create the Batch Job
print("Starting batch job...")
batch_job = client.batches.create(
    input_file_id=batch_file.id,
    endpoint="/v1/chat/completions",
    completion_window="24h"
)

print("-" * 30)
print(f"SUCCESS! Batch Job Created.")
print(f"Batch ID: {batch_job.id}")
print("-" * 30)
print("SAVE THIS BATCH ID. You will need it for Script 2.")
