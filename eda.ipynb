# %%
# !pip install --upgrade pip -q
# !pip install psycopg2-binary -q
# !pip install SQLAlchemy -q
# !pip install spacy -q
# !python -m spacy download en_core_web_sm -q
# Out:
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# C:\Users\arvin\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip -q
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# WARNING: Ignoring invalid distribution ~yspark (c:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yspark (c:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yspark (c:\Users\arvin\AppData\Local\Programs\Python\Python313\Lib\site-packages)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import socket

import pandas as pd
from sqlalchemy import create_engine

# %%
host = "awesome-hw.sdsc.edu"
port = 5432  # PostgreSQL default port

try:
    socket.create_connection((host, port), timeout=5)
    print("✅ Host is reachable — network connection works.")
except Exception as e:
    print("❌ Cannot reach host:", e)
# Out:
# ✅ Host is reachable — network connection works.

# %%
# Connection parameters
host = "awesome-hw.sdsc.edu"
port = 5432
database = "nourish"
user = "akrish"  # <–– given this by TA
password = "dse203#2025"  # <–– your PostgreSQL password

# Create the connection engine
engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}")

# Test the connection
try:
    with engine.connect() as conn:
        print("✅ Connected successfully!")
except Exception as e:
    print("❌ Connection failed:", e)
# Out:
# ✅ Connected successfully!

# %%
query = """
        SELECT table_name
        FROM information_schema.tables
        WHERE table_schema = 'public'
        ORDER BY table_name; \
        """

tables = pd.read_sql(query, engine)
print(tables)
# Out:
#                                            table_name
# 0                                       ArcGIS_Schema
# 1                                             CA-CDFI
# 2    ESRI_SD_County_Tract_Level_Market_Potential_Data
# 3            ESRI_SD_County_Tract_Level_business_data
# 4        ESRI_SD_County_Tract_Level_consumer_spending
# ..                                                ...
# 134          usda_2022_food_calorie_conversion_factor
# 135                           usda_2022_food_portions
# 136          usda_2022_food_protein_conversion_factor
# 137                         usda_2022_nutrient_master
# 138                                             users
#
# [139 rows x 1 columns]

# %%
# query 50 rows
query = "SELECT * FROM \"FoodKG\" LIMIT 50;"  # quotes protect uppercase table names

df = pd.read_sql(query, engine)

# display nicely
pd.set_option('display.max_columns', None)  # show all columns
pd.set_option('display.max_rows', 50)  # show up to 50 rows
display(df)
# Out:
#      id                                      title  \
# 0   715                              Zucchini Stew
# 1   716                             Party Potatoes
# 2   717                  Gran'S Toll House Cookies
# 3   718  Hominy Casserole(Large Recipe; Make Half)
# 4   720             Poached Chicken Breast In Wine
# 5   721               Quick Spanish Rice Casserole
# 6   722                              Glazed Pecans
# 7   723                            Crock Pot Pizza
# 8   724                    Summer Squash Casserole
# 9   725                          Green Jello Salad
# 10  729                     Never Fail Jello Salad
# 11  730                              Fruit Cobbler
# 12  731                            Poppy Seed Cake
# 13  732                                  Magloubeh
# 14  733                    Whole Wheat Carrot Cake
# 15  734                             Pickled Squash
# 16  735                                Pasta Salad
# 17  736                      Vegetable Burger Soup
# 18  737                           Corn Light Bread
# 19  739                      Crustless Pumpkin Pie
# 20  793                                 Taco Beans
# 21  740                                 D'S Danish
# 22  741                        Picnic Potato Salad
# 23  743                          Chicken Fettucini
# 24  745                         Lemon Chip Cookies
# 25  746                              Pineapple Pie
# 26  747                          Persimmon Pudding
# 27  748                                  Pie Crust
# 28  749                   Cajun Crawfish Cornbread
# 29  761                     Sausages And Seashells
# 30  750             Fat-Free Banana Crunch Muffins
# 31  752                        Spaghetti Casserole
# 32  753                         Cold Bread Pudding
# 33  754                             Persimmon Cake
# 34  755                        Graham Cracker Cake
# 35  756                            No Bake Cookies
# 36  757         Butterscotch Squares(Servings:  4)
# 37  758                     Sausage And Egg Quiche
# 38  759                             Date Nut Balls
# 39  760                       Broccoli Cheese Soup
# 40  762      Barbara Mandrell'S Four Layer Dessert
# 41  763                             Zucchini Bread
# 42  764                                Corn Crepes
# 43  765                            Spaghetti Salad
# 44  766                                  Ham Balls
# 45  767                  Low Cholesterol Ice Cream
# 46  768                                       Glop
# 47  769               Spanakopeta(Spinach Squares)
# 48  770                      Hot And Spicy Chicken
# 49  771                           Oven Swiss Steak
#
#                                           ingredients  \
# 0   [2 large zucchini, cut in large cubes, 2 green...
# 1   [4 c. mashed potatoes, 1 pkg. Hidden Valley Ra...
# 2   [1 1/2 c. sifted flour, 1 tsp. soda, 1 tsp. sa...
# 3   [2 cans yellow hominy, drained, 1/2 stick oleo...
# 4   [4 (4 oz.) skinned, boned chicken breast halve...
# 5   [2 cans Brown Beauty Spanish rice, 1 or 2 cans...
# 6   [1 lb. pecan halves, 1 tbsp. water, 1 tsp. sal...
# 7   [1 1/2 pounds hamburger, 2 small jars pizza sa...
# 8   [2 lb. yellow sumer squash or zucchini, sliced...
# 9   [2 pkg. lime Jell-O, 1 carton cottage cheese, ...
# 10  [1 large jello (any flavor), 1 c. boiling wate...
# 11  [3/4 stick margarine, fruit of your choice (I ...
# 12  [4 eggs, 1/4 c. poppy seed, 1/2 c. pineapple j...
# 13  [2 lb. chicken or lamb, 1 lb. rice, 2 large eg...
# 14  [1 c. oil, 1 c. brown sugar, 4 eggs, 1/3 c. dr...
# 15  [8 c. sliced squash, 8 c. sliced onions, 5 bel...
# 16  [1/4 lb. Provolone cheese, 1/4 lb. salami, 1/4...
# 17  [1 lb. ground beef, 1 (16 oz.) can tomatoes, 1...
# 18  [2 c. self-rising meal, 1/2 c. plain flour, 3/...
# 19  [3 eggs, 3/4 c. honey, 1/2 tsp. ginger, 1/2 ts...
# 20  [2 lb. pinto beans, 2 lb. ground meat, 2 cans ...
# 21  [4 c. flour, 3 tsp. sugar, 1 tsp. salt, 1 c. o...
# 22  [1 1/2 cooked potatoes, 3 hard-boiled eggs, 3/...
# 23  [1 c. butter, 4 chicken bouillon cubes, 8 shal...
# 24  [2 c. flour, 1/2 c. sugar, 3 oz. cream cheese,...
# 25  [1 c. sugar, 1 Tbsp. plain flour, 3 eggs, sepa...
# 26  [2 c. persimmon pulp, 2 c. sugar or less, 2 eg...
# 27  [4 c. flour, 1 3/4 c. Crisco, 1 Tbsp. sugar, 1...
# 28  [2 c. cornmeal, 1 tsp. salt, 1 tsp. baking pow...
# 29  [1 lb. small seashells pasta, 8 Italian sweet ...
# 30  [1 c. all-purpose flour, 1/2 c. wheat and barl...
# 31  [1 small pkg. spaghetti, 1 lb. hamburger, 1 on...
# 32  [cold biscuits (crumbled), sweet milk (for soa...
# 33  [3 c. persimmons, cut in chunks, 2 tsp. baking...
# 34  [1 lb. box graham crackers, crushed, 2 c. suga...
# 35  [1 stick oleo, 1/3 c. cocoa, 2 c. sugar, 1/2 c...
# 36  [1 lb. margarine or butter, 2 lb. 8 oz. brown ...
# 37  [2 pie shells, 1 lb. sausage, 8 eggs, 2 c. shr...
# 38  [1 1/2 sticks butter (not oleo or margarine), ...
# 39  [1 1/2 c. chopped onion, 1/2 c. butter or marg...
# 40  [1 c. flour, 1 c. chopped nuts, 1/2 c. melted ...
# 41  [3 eggs, 1 c. oil, 2 c. sugar, 3 tsp. vanilla,...
# 42  [2 eggs, 2 egg yolks, 2 c. milk, 1 c. flour, 1...
# 43  [1 lb. cooked spaghetti, 1 green pepper, diced...
# 44  [1 lb. grated ham, 8 oz. sharp Cheddar cheese,...
# 45  [1 box Egg Scramblers (2 eggs), 2 c. sugar, 1 ...
# 46  [1 small onion, 3 to 5 potatoes, sliced thin, ...
# 47  [2 bunches green onion, finely chopped, 1 onio...
# 48  [3 chicken breasts, skinned, cooked and choppe...
# 49  [1 1/2 lb. round (or sirloin) steak, cut in pi...
#
#                                            directions  \
# 0   [Heat oil in large saucepot; add zucchini, pep...
# 1   [Prepare mashed potatoes as you normally would...
# 2   [Sift flour once before measuring, then sift w...
# 3   [Butter dish; cook onion in oleo., Add soup, h...
# 4   [Place, chicken between two sheets of heavy-du...
# 5   [Brown meat and onion., Add salt and pepper to...
# 6   [1st bowl - Combine water and egg white and be...
# 7   [Brown meat with onions and peppers and drain....
# 8   [In a saucepan cook sliced squash and chopped ...
# 9   [Dissolve Jell-O in 1 cup boiling water., Add ...
# 10  [Dissolve jello with boiling water, then disso...
# 11  [Melt margarine., Put in 2-inch deep dish., Ad...
# 12  [Beat first 6 ingredients for 2 minutes., Then...
# 13  [Soak the rice for 1 hour in warm water., Cook...
# 14  [In large mixing bowl blend oil and sugars unt...
# 15  [Soak squash, onions and peppers in salt water...
# 16           [Dice and mix all ingredients together.]
# 17  [Brown meat and drain off fat., Stir in 2 cups...
# 18  [Mix ingredients and pour into a regular size ...
# 19  [Beat eggs., Add the next 6 ingredients and mi...
# 20  [Cook beans., Brown meat, then add other ingre...
# 21  [Mix flour,, sugar,, salt,, andtoleo, as for p...
# 22  [Coarsely dice potatoes and eggs with salt, pe...
# 23  [In double boiler, melt butter with bouillon c...
# 24  [Mix first 4 ingredients., Pack in 9 x 13-inch...
# 25  [Sift sugar and flour together., Mix all ingre...
# 26  [Preheat oven to 325u00b0., Melt margarine in ...
# 27  [Mix dry ingredients (flour, sugar and salt).,...
# 28  [In bowl, combine cornmeal, salt and soda., In...
# 29  [Prick the sausages with a sharp fork, cover w...
# 30  [About 40 minutes before serving or early in t...
# 31  [Brown hamburger, onion and pepper in skillet ...
# 32  [One mixing bowl of crumbled up cold biscuits ...
# 33  [Heat oven to 350u00b0., Mix together the pers...
# 34  [Mix sugar, eggs and margarine in bowl, then a...
# 35  [Put oleo, cocoa, sugar and milk in saucepan.,...
# 36  [Cream margarine and sugar on medium speed for...
# 37  [Brown sausage and drain off fat., Beat eggs.,...
# 38  [Cook butter, dates and sugar until very thick...
# 39  [In a large saucepan, saute onion in butter., ...
# 40  [Combine flour, nuts and melted margarine and ...
# 41  [Beat eggs; add oil, sugar and vanilla., Mix w...
# 42  [In blender combine eggs, egg yolks, milk, flo...
# 43  [Cook spaghetti., Dice vegetables together., A...
# 44               [Roll in balls and bake 10 minutes.]
# 45  [Beat Scramblers in large bowl., Mix in evapor...
# 46  [Slice potatoes and onion., Put on bottom of p...
# 47  [Saut onions in butter until soft., Add spinac...
# 48  [Combine chicken, corn, broth, celery and onio...
# 49  [Shake 1 tablespoon flour in the oven cooking ...
#
#                                                 link    source  \
# 0    www.cookbooks.com/Recipe-Details.aspx?id=427946  Gathered
# 1    www.cookbooks.com/Recipe-Details.aspx?id=739625  Gathered
# 2    www.cookbooks.com/Recipe-Details.aspx?id=454436  Gathered
# 3    www.cookbooks.com/Recipe-Details.aspx?id=702142  Gathered
# 4    www.cookbooks.com/Recipe-Details.aspx?id=714034  Gathered
# 5    www.cookbooks.com/Recipe-Details.aspx?id=706929  Gathered
# 6     www.cookbooks.com/Recipe-Details.aspx?id=63598  Gathered
# 7     www.cookbooks.com/Recipe-Details.aspx?id=70331  Gathered
# 8    www.cookbooks.com/Recipe-Details.aspx?id=930887  Gathered
# 9   www.cookbooks.com/Recipe-Details.aspx?id=1074917  Gathered
# 10   www.cookbooks.com/Recipe-Details.aspx?id=877953  Gathered
# 11   www.cookbooks.com/Recipe-Details.aspx?id=927499  Gathered
# 12   www.cookbooks.com/Recipe-Details.aspx?id=264391  Gathered
# 13   www.cookbooks.com/Recipe-Details.aspx?id=331071  Gathered
# 14   www.cookbooks.com/Recipe-Details.aspx?id=227296  Gathered
# 15   www.cookbooks.com/Recipe-Details.aspx?id=589097  Gathered
# 16  www.cookbooks.com/Recipe-Details.aspx?id=1077131  Gathered
# 17   www.cookbooks.com/Recipe-Details.aspx?id=302429  Gathered
# 18   www.cookbooks.com/Recipe-Details.aspx?id=132569  Gathered
# 19   www.cookbooks.com/Recipe-Details.aspx?id=309992  Gathered
# 20   www.cookbooks.com/Recipe-Details.aspx?id=456421  Gathered
# 21   www.cookbooks.com/Recipe-Details.aspx?id=307746  Gathered
# 22   www.cookbooks.com/Recipe-Details.aspx?id=240076  Gathered
# 23   www.cookbooks.com/Recipe-Details.aspx?id=640404  Gathered
# 24   www.cookbooks.com/Recipe-Details.aspx?id=639713  Gathered
# 25   www.cookbooks.com/Recipe-Details.aspx?id=522957  Gathered
# 26   www.cookbooks.com/Recipe-Details.aspx?id=392389  Gathered
# 27   www.cookbooks.com/Recipe-Details.aspx?id=221232  Gathered
# 28   www.cookbooks.com/Recipe-Details.aspx?id=164591  Gathered
# 29   www.cookbooks.com/Recipe-Details.aspx?id=251703  Gathered
# 30   www.cookbooks.com/Recipe-Details.aspx?id=777590  Gathered
# 31   www.cookbooks.com/Recipe-Details.aspx?id=529173  Gathered
# 32    www.cookbooks.com/Recipe-Details.aspx?id=91723  Gathered
# 33   www.cookbooks.com/Recipe-Details.aspx?id=750527  Gathered
# 34   www.cookbooks.com/Recipe-Details.aspx?id=705246  Gathered
# 35   www.cookbooks.com/Recipe-Details.aspx?id=761506  Gathered
# 36  www.cookbooks.com/Recipe-Details.aspx?id=1008912  Gathered
# 37   www.cookbooks.com/Recipe-Details.aspx?id=600748  Gathered
# 38   www.cookbooks.com/Recipe-Details.aspx?id=136387  Gathered
# 39   www.cookbooks.com/Recipe-Details.aspx?id=972702  Gathered
# 40   www.cookbooks.com/Recipe-Details.aspx?id=453861  Gathered
# 41  www.cookbooks.com/Recipe-Details.aspx?id=1011935  Gathered
# 42   www.cookbooks.com/Recipe-Details.aspx?id=766867  Gathered
# 43   www.cookbooks.com/Recipe-Details.aspx?id=334826  Gathered
# 44  www.cookbooks.com/Recipe-Details.aspx?id=1073172  Gathered
# 45   www.cookbooks.com/Recipe-Details.aspx?id=289172  Gathered
# 46   www.cookbooks.com/Recipe-Details.aspx?id=898159  Gathered
# 47   www.cookbooks.com/Recipe-Details.aspx?id=138725  Gathered
# 48   www.cookbooks.com/Recipe-Details.aspx?id=696196  Gathered
# 49   www.cookbooks.com/Recipe-Details.aspx?id=379288  Gathered
#
#                                                   ner
# 0   [zucchini, green, onions, tomatoes, oil, green...
# 1                                          [potatoes]
# 2   [flour, soda, salt, shortening, brown sugar, s...
# 3   [yellow hominy, oleo, onion, cream of mushroom...
# 4   [Chablis, mushrooms, parsley, salt, pepper, co...
# 5   [rice, beans, ground meat, onion, Cheddar chee...
# 6   [pecan halves, water, salt, egg, sugar, cinnamon]
# 7   [hamburger, pizza sauce, pizza cheese, mushroo...
# 8   [yellow sumer squash, onion, condensed cream, ...
# 9   [lime Jell-O, cottage cheese, pineapple, sugar...
# 10  [jello, boiling water, marshmallows, cottage c...
# 11       [margarine, your choice, sugar, milk, flour]
# 12  [eggs, poppy seed, pineapple juice, white cake...
# 13  [chicken, rice, eggplant, cauliflower, potatoe...
# 14  [oil, brown sugar, eggs, milk powder, baking p...
# 15  [squash, onions, bell peppers, salt, vinegar, ...
# 16  [Provolone cheese, salami, pepperoni, pepper, ...
# 17  [ground beef, tomatoes, tomato sauce, frozen m...
# 18  [meal, flour, sugar, salt, baking powder, soda...
# 19  [eggs, honey, ginger, nutmeg, cinnamon, salt, ...
# 20  [pinto beans, ground meat, taco sauce, green c...
# 21  [flour, sugar, salt, oleo, eggs, warm milk, ye...
# 22  [potatoes, eggs, salt, celery, celery, mustard...
# 23  [butter, chicken bouillon cubes, shallots, whi...
# 24  [flour, sugar, cream cheese, margarine, eggs, ...
# 25  [sugar, flour, eggs, pineapple, vanilla, marga...
# 26  [persimmon pulp, sugar, eggs, milk, flour, cin...
# 27  [flour, Crisco, sugar, salt, egg, vinegar, water]
# 28  [cornmeal, salt, baking powder, eggs, onions, ...
# 29  [pasta, Italian sweet sausages, olive oil, oni...
# 30  [flour, cereal nuggets, sugar, baking powder, ...
# 31  [spaghetti, hamburger, onion, green pepper, to...
# 32            [cold, sweet milk, butter, eggs, sugar]
# 33  [persimmons, baking soda, butter, sugar, eggs,...
# 34  [graham crackers, sugar, margarine, pecans, mi...
# 35  [oleo, cocoa, sugar, milk, oatmeal, peanut but...
# 36  [margarine, brown sugar, eggs, vanilla, flour,...
# 37  [pie shells, sausage, eggs, Cheddar cheese, Mo...
# 38  [butter, dates, sugar, pecans, Rice Krispies, ...
# 39  [onion, butter, all-purpose, condensed chicken...
# 40  [flour, nuts, margarine, cream cheese, topping...
# 41  [eggs, oil, sugar, vanilla, flour, soda, salt,...
# 42  [eggs, egg yolks, milk, flour, ground cornmeal...
# 43  [green pepper, onion, cucumber, celery, tomato...
# 44             [grated ham, Cheddar cheese, Bisquick]
# 45       [Egg Scramblers, sugar, vanilla, milk, milk]
# 46  [onion, potatoes, green beans, hamburger, cele...
# 47  [green onion, onion, butter, spinach, cream ch...
# 48  [chicken breasts, frozen corn, celery, chicken...
# 49  [Italian seasoned tomatoes, onion soup, salt, ...

# %%
# Only fetch the column names without data
columns = pd.read_sql("SELECT * FROM \"FoodKG\" LIMIT 0;", engine).columns
print(columns)
# Out:
# Index(['id', 'title', 'ingredients', 'directions', 'link', 'source', 'ner'], dtype='object')

# %%
import spacy
import re

nlp = spacy.load("en_core_web_sm")

# Common measurement units to remove
units = ['c', 'cup', 'cups', 'tbsp', 'tsp', 'oz', 'g', 'kg', 'ml', 'l', 'pinch', 'slice', 'clove', 'cloves']
pattern_units = r'\b(?:' + '|'.join(units) + r')\b'

# Process every recipe
all_cleaned_ingredients = []

for ingredient_list in df['ingredients']:
    recipe_ingredients = []
    for ing in ingredient_list:
        # lowercase
        ing_clean = ing.lower()
        # remove numbers and fractions
        ing_clean = re.sub(r'\d+\/\d+|\d+', '', ing_clean)
        # remove units
        ing_clean = re.sub(pattern_units, '', ing_clean)
        # remove punctuation and extra spaces
        ing_clean = re.sub(r'[^a-zA-Z\s]', '', ing_clean)
        ing_clean = re.sub(r'\s+', ' ', ing_clean).strip()

        # use SpaCy to extract nouns
        doc = nlp(ing_clean)
        nouns = [token.text for token in doc if token.pos_ == 'NOUN']

        if nouns:
            recipe_ingredients.append(' '.join(nouns))

    all_cleaned_ingredients.append(recipe_ingredients)

# Add it back to the dataframe as a new column
df['cleaned_ingredients'] = all_cleaned_ingredients

# Display first 5 recipes
df[['ingredients', 'cleaned_ingredients']].head()
# Out:
#                                          ingredients  \
# 0  [2 large zucchini, cut in large cubes, 2 green...
# 1  [4 c. mashed potatoes, 1 pkg. Hidden Valley Ra...
# 2  [1 1/2 c. sifted flour, 1 tsp. soda, 1 tsp. sa...
# 3  [2 cans yellow hominy, drained, 1/2 stick oleo...
# 4  [4 (4 oz.) skinned, boned chicken breast halve...
#
#                                  cleaned_ingredients
# 0  [zucchini cut cubes, peppers, onions, size tom...
# 1              [potatoes, valley ranch dressing mix]
# 2  [flour, salt, shortening, sugar, sugar, water,...
# 3          [cans, onion, mushroom soup, jar, fritos]
# 4  [chicken breast halves, wine, mushrooms, parsl...

# %%
query = 'SELECT COUNT(*) AS total_rows FROM "FoodKG";'

result = pd.read_sql(query, engine)
print(result["total_rows"].iloc[0])
# Out:
# 2231142

# %%
query = """
SELECT
    id,
    title,
    ingredients,
    ner
FROM
    "FoodKG"
LIMIT 500;
"""

result = pd.read_sql(query, engine)
print(result)
# Out:
#        id                                              title  \
# 0     715                                      Zucchini Stew
# 1     716                                     Party Potatoes
# 2     717                          Gran'S Toll House Cookies
# 3     718          Hominy Casserole(Large Recipe; Make Half)
# 4     720                     Poached Chicken Breast In Wine
# ..    ...                                                ...
# 495  1229                          Chicken-Mexican Casserole
# 496  1230                   Chocolate Pudding Or Pie Filling
# 497  1231  Taco Salad(Easier For Kids To Eat Than Traditi...
# 498  1232                                Fast Fudge Frosting
# 499  1233                                 Au Gratin Potatoes
#
#                                            ingredients  \
# 0    [2 large zucchini, cut in large cubes, 2 green...
# 1    [4 c. mashed potatoes, 1 pkg. Hidden Valley Ra...
# 2    [1 1/2 c. sifted flour, 1 tsp. soda, 1 tsp. sa...
# 3    [2 cans yellow hominy, drained, 1/2 stick oleo...
# 4    [4 (4 oz.) skinned, boned chicken breast halve...
# ..                                                 ...
# 495  [1 (10 1/2 oz.) can cream of chicken soup, 1 (...
# 496  [1 c. sugar, 3 Tbsp. flour, 1 1/2 Tbsp. cocoa,...
# 497  [1 lb. TVP beef granules, 1 medium onion, chop...
# 498  [1 pkg. confectioners sugar, sifted (4 1/2 c.)...
# 499  [4 medium potatoes, peeled and cut in 1/4-inch...
#
#                                                    ner
# 0    [zucchini, green, onions, tomatoes, oil, green...
# 1                                           [potatoes]
# 2    [flour, soda, salt, shortening, brown sugar, s...
# 3    [yellow hominy, oleo, onion, cream of mushroom...
# 4    [Chablis, mushrooms, parsley, salt, pepper, co...
# ..                                                 ...
# 495  [cream of chicken soup, chiles, onion, water, ...
# 496  [sugar, flour, cocoa, eggs, sweet milk, vanill...
# 497  [beef granules, onion, taco seasoning mix, hot...
# 498  [confectioners sugar, cocoa, salt, boiling wat...
# 499  [potatoes, oil, onions, garlic powder, salt, b...
#
# [500 rows x 4 columns]

# %%
query = """
SELECT
    id,
    name
FROM
    usda_2022_nutrient_master
LIMIT 500;
"""

result = pd.read_sql(query, engine)
print(result)
# Out:
#        id                                        name
# 0    2047            Energy (Atwater General Factors)
# 1    2048           Energy (Atwater Specific Factors)
# 2    1001                                      Solids
# 3    1002                                    Nitrogen
# 4    1003                                     Protein
# ..    ...                                         ...
# 469  2061                         Ergosta-7,22-dienol
# 470  2062                          Ergosta-5,7-dienol
# 471  2063                                  Verbascose
# 472  2064                            Oligosaccharides
# 473  2065  Low Molecular Weight Dietary Fiber (LMWDF)
#
# [474 rows x 2 columns]

# %%
query = """
SELECT
    fdc_id,
    description
FROM
    usda_2022_food_branded_experimental
LIMIT 500;
"""

result = pd.read_sql(query, engine)
print(result)
# Out:
#       fdc_id                                        description
# 0    1105904                         WESSON Vegetable Oil 1 GAL
# 1    1105905                                 SWANSON BROTH BEEF
# 2    1105906           CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER
# 3    1105907        CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI
# 4    1105898  Discrepancy between the Atwater factor predict...
# ..       ...                                                ...
# 495  1106392  MEATLOAF WITH PORTOBELLO MUSHROOM GRAVY MEATLO...
# 496  1106393  CRUSTLESS CHICKEN POT PIE WHITE MEAT CHICKEN, ...
# 497  1106394                                          BBQ SAUCE
# 498  1106395           THAI-STYLE COCONUT CHICKEN, MEDIUM SPICY
# 499  1106396                                    SHRIMP PAD THAI
#
# [500 rows x 2 columns]

# %%
query = """
SELECT
    id,
    fdc_id,
    nutrient_id
FROM
    usda_2022_branded_food_nutrients
LIMIT 500;
"""

result = pd.read_sql(query, engine)
print(result)
# Out:
#            id   fdc_id  nutrient_id
# 0    13706913  1105904         1003
# 1    13706914  1105904         1004
# 2    13706915  1105904         1005
# 3    13706924  1105904         1110
# 4    13706918  1105904         1079
# ..        ...      ...          ...
# 495  13707096  1105935         2000
# 496  13707094  1105935         1005
# 497  13707101  1105935         1093
# 498  13707100  1105935         1092
# 499  13707099  1105935         1089
#
# [500 rows x 3 columns]
