# %%
import ast
from collections import Counter

import pandas as pd

# %%
df = pd.read_csv("data/SpacyProcessing/v1/foodkg_spacy_processed.csv")
df.head(5)
# Out:
#    recipe_id                               original_ingredients  \
# 0          0  ['1 c. firmly packed brown sugar', '1/2 c. eva...
# 1          1  ['1 small jar chipped beef, cut up', '4 boned ...
# 2          2  ['2 (16 oz.) pkg. frozen corn', '1 (8 oz.) pkg...
# 3          3  ['1 large whole chicken', '2 (10 1/2 oz.) cans...
# 4          4  ['1 c. peanut butter', '3/4 c. graham cracker ...
#
#                                processed_ingredients
# 0  ['brown sugar', 'milk', 'vanilla', 'nut', 'but...
# 1  ['beef', 'chicken breast', 'cream mushroom sou...
# 2  ['corn', 'cream cheese', 'butter', 'garlic', '...
# 3  ['chicken', 'chicken gravy', 'cream mushroom s...
# 4  ['peanut butter', 'graham cracker crumb', 'but...

# %%
df[df['recipe_id'] == 388422]
# Out:
#         recipe_id                               original_ingredients  \
# 388422     388422  ['1/2 c. butter, melted', '1 1/3 c. flour', '1...
#
#                processed_ingredients
# 388422  ['butter', 'flour', 'sugar']

# %%
foodkg_df = pd.read_csv('data/raw/nourish_public_FoodKG.csv')
foodkg_df.head(5)
# Out:
#         id                                              title  \
# 0  2229479                     Double Chocolate Chewy Cookies
# 1  2229480  "Old Fashioned Potato Soup - "Homemade" Potato...
# 2  2229492  Persian pasta with spiced chickpeas and pistac...
# 3  2229494               Shawn & Lauras Kitchen Sink Feijoada
# 4  2229498  The 4:2:1 Golden Ratio for Always Delicious Ta...
#
#                                          ingredients  \
# 0  ['3/4 cup softened salted butter', '1 1/2 cup ...
# 1  ['6 Potatoes, peeled, cubes', '2 Leeks, washed...
# 2  ['250 g (8.8oz) spaghetti', '1 tin of chickpea...
# 3  ['1 12 tablespoons garlic (chopped)', '1 shall...
# 4  ['4 Eggs (large)', '2 tbsp Sugar', '1 tsp Salt...
#
#                                           directions  \
# 0  ['Heat oven to 350F.', 'Cream butter and sugar...
# 1  ['Put all ingredients except milk and chives i...
# 2  ['Boil a large pot of water for your pasta.', ...
# ...

# %%
foodkg_df[foodkg_df['id'] == 388422]
# Out:
#             id                  title  \
# 369554  388422  Lemon Butter Snowbars
#
#                                               ingredients  \
# 369554  ['1/2 c. butter, melted', '1 1/3 c. flour', '1...
#
#                                                directions  \
# 369554  ['Pat into ungreased pan.', 'Bake 15 minutes a...
#
#                                                    link    source  \
# 369554  www.cookbooks.com/Recipe-Details.aspx?id=510717  Gathered
#
#                                  ner
# 369554  ['butter', 'flour', 'sugar']
