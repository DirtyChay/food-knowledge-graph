# %%
import ast
import json

import pandas as pd

# %%
# convert "['a','b']" to a set {'a', 'b'}
def to_set(x):
    list_string = json.loads(x)
    list_raw = ast.literal_eval(list_string)
    return set(list_raw)

# %%
# Read the CSV
pred_df = pd.read_csv("data/output/processed_ingredients.csv")
test_df = pd.read_csv("../data/test/TEST_FoodKG_ingredients_normalized.csv")
# Rename the test column so we don't clash on merge
test_df_renamed = test_df.rename(columns={"ingredients_normalized": "ingredients_test"})
# Merge using test_df as the left df to keep its order
merged_df = test_df_renamed[["id", "ingredients_test"]].merge(
    pred_df, on="id", how="inner"
)
merged_df.head()
# Out:
#    id                                   ingredients_test  \
# 0   0  "['brown sugar', 'evaporated milk', 'vanilla',...
# 1   1  "['chipped beef', 'chicken breast', 'cream of ...
# 2   2  "['corn', 'cream cheese', 'butter', 'garlic po...
# 3   3  "['whole chicken', 'chicken gravy', 'cream of ...
# 4   4  "['peanut butter', 'graham cracker', 'butter',...
#
#                    title                                        ingredients  \
# 0    No-Bake Nut Cookies  ['1 c. firmly packed brown sugar', '1/2 c. eva...
# 1  Jewell Ball'S Chicken  ['1 small jar chipped beef, cut up', '4 boned ...
# 2            Creamy Corn  ['2 (16 oz.) pkg. frozen corn', '1 (8 oz.) pkg...
# 3          Chicken Funny  ['1 large whole chicken', '2 (10 1/2 oz.) cans...
# 4     Reeses Cups(Candy)  ['1 c. peanut butter', '3/4 c. graham cracker ...
#
#                               ingredients_normalized
# 0  "['brown sugar', 'evaporated milk', 'vanilla',...
# 1  "['chipped beef', 'chicken breast', 'cream of ...
# 2  "['corn', 'cream cheese', 'butter', 'garlic po...
# 3  "['chicken', 'chicken gravy', 'mushroom soup',...
# 4  "['peanut butter', 'graham cracker crumb', 'bu...

# %%
pred_sets = [to_set(x) for x in merged_df["ingredients_normalized"]]
test_sets = [to_set(x) for x in merged_df["ingredients_test"]]

new_df = pd.DataFrame({
    "id": merged_df["id"],
    "ingredients": merged_df["ingredients"],
    "pred_set": pred_sets,
    "test_set": test_sets,
})
new_df.head()
# Out:
#    id                                        ingredients  \
# 0   0  ['1 c. firmly packed brown sugar', '1/2 c. eva...
# 1   1  ['1 small jar chipped beef, cut up', '4 boned ...
# 2   2  ['2 (16 oz.) pkg. frozen corn', '1 (8 oz.) pkg...
# 3   3  ['1 large whole chicken', '2 (10 1/2 oz.) cans...
# 4   4  ['1 c. peanut butter', '3/4 c. graham cracker ...
#
#                                             pred_set  \
# 0  {brown sugar, vanilla, shredded rice biscuit, ...
# 1  {cream of mushroom soup, sour cream, chicken b...
# 2  {cream cheese, garlic powder, salt, corn, butt...
# 3  {mushroom soup, chicken, chicken gravy, cheese...
# 4  {graham cracker crumb, peanut butter, powdered...
#
#                                             test_set
# 0  {brown sugar, rice biscuit, vanilla, butter, e...
# 1  {cream of mushroom soup, sour cream, chicken b...
# 2  {cream cheese, garlic powder, salt, corn, blac...
# 3  {whole chicken, cream of mushroom soup, chicke...
# 4  {peanut butter, powdered sugar, butter, graham...

# %%
def precision_recall_f1_per_row(row):
    pred = row["pred_set"]
    test = row["test_set"]

    tp = len(pred & test)
    fp = len(pred - test)
    fn = len(test - pred)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0

    return pd.Series({"precision": precision, "recall": recall, "f1": f1})


def calculate_overlap(row):
    intersection_size = len(row["pred_set"] & row["test_set"])
    n = max(len(row["pred_set"]), len(row["test_set"]))
    if n == 0: return 0
    return intersection_size / n


def calculate_jaccard(row):
    intersection_size = row['intersection_size']
    union_size = row['union_size']
    if union_size == 0: return 0
    return intersection_size / union_size

# %%
# Elements that differ
new_df["pred_only"] = new_df["pred_set"] - new_df["test_set"]
new_df["test_only"] = new_df["test_set"] - new_df["pred_set"]
# intersection size
new_df["intersection_size"] = new_df.apply(
    lambda row: len(row["pred_set"] & row["test_set"]), axis=1
)
# union size
new_df["union_size"] = new_df.apply(
    lambda row: len(row["pred_set"] | row["test_set"]), axis=1
)
# overlap = intersection / larger_set
new_df["overlap"] = new_df.apply(calculate_overlap, axis=1)
# Jaccard similarity (intersection / union)
new_df["jaccard"] = new_df.apply(calculate_jaccard, axis=1)
# Precision, recall, F1
new_df[["precision", "recall", "f1"]] = new_df.apply(precision_recall_f1_per_row, axis=1)

# %%
new_df.head(100)
# Out:
#     id                                        ingredients  \
# 0    0  ['1 c. firmly packed brown sugar', '1/2 c. eva...
# 1    1  ['1 small jar chipped beef, cut up', '4 boned ...
# 2    2  ['2 (16 oz.) pkg. frozen corn', '1 (8 oz.) pkg...
# 3    3  ['1 large whole chicken', '2 (10 1/2 oz.) cans...
# 4    4  ['1 c. peanut butter', '3/4 c. graham cracker ...
# ..  ..                                                ...
# 95  95  ['3 (1 lb.) cans pork and beans', '1/2 c. bell...
# 96  96  ['2 c. diced cooked chicken', '2 Tbsp. shorten...
# 97  97  ['8 to 10 juicy oranges, peeled and diced', '1...
# 98  98  ['1 c. creamy peanut butter', '1 c. sugar', '1...
# 99  99  ['1 box yellow cake mix', '2 eggs', '1/3 c. so...
#
#                                              pred_set  \
# 0   {brown sugar, vanilla, shredded rice biscuit, ...
# 1   {cream of mushroom soup, sour cream, chicken b...
# 2   {cream cheese, garlic powder, salt, corn, butt...
# 3   {mushroom soup, chicken, chicken gravy, cheese...
# 4   {graham cracker crumb, peanut butter, powdered...
# ..                                                ...
# 95  {brown sugar, pork and beans, oil, salt, black...
# 96  {brown sugar, ginger, water, green pepper, pin...
# 97  {sugar, coconut, pecan, orange, orange juice, ...
# 98                        {sugar, egg, peanut butter}
# 99  {yellow cake mix, bit, egg, soft margarine, mi...
#
#                                              test_set  \
# 0   {brown sugar, rice biscuit, vanilla, butter, e...
# 1   {cream of mushroom soup, sour cream, chicken b...
# 2   {cream cheese, garlic powder, salt, corn, blac...
# 3   {whole chicken, cream of mushroom soup, chicke...
# 4   {peanut butter, powdered sugar, butter, graham...
# ..                                                ...
# 95  {brown sugar, pork and beans, oil, salt, black...
# 96  {brown sugar, ginger, water, green pepper, pin...
# 97  {sugar, coconut, pecan, orange, orange juice, ...
# 98                        {sugar, egg, peanut butter}
# 99  {toffee bit, yellow cake mix, egg, milk, marga...
#
#                    pred_only                                test_only  \
# 0    {shredded rice biscuit}                {margarine, rice biscuit}
# 1                         {}                                       {}
# 2                   {pepper}                           {black pepper}
# 3   {mushroom soup, chicken}  {whole chicken, cream of mushroom soup}
# 4     {graham cracker crumb}                         {graham cracker}
# ..                       ...                                      ...
# 95                        {}                                       {}
# 96                        {}                                       {}
# 97                        {}                                       {}
# 98                        {}                                       {}
# 99     {bit, soft margarine}                  {toffee bit, margarine}
#
#     intersection_size  union_size   overlap   jaccard  precision    recall  \
# 0                   5           8  0.714286  0.625000   0.833333  0.714286
# 1                   4           4  1.000000  1.000000   1.000000  1.000000
# 2                   5           7  0.833333  0.714286   0.833333  0.833333
# 3                   3           7  0.600000  0.428571   0.600000  0.600000
# 4                   4           6  0.800000  0.666667   0.800000  0.800000
# ..                ...         ...       ...       ...        ...       ...
# 95                  9           9  1.000000  1.000000   1.000000  1.000000
# 96                 14          14  1.000000  1.000000   1.000000  1.000000
# 97                  6           6  1.000000  1.000000   1.000000  1.000000
# 98                  3           3  1.000000  1.000000   1.000000  1.000000
# 99                  4           8  0.666667  0.500000   0.666667  0.666667
#
#           f1
# 0   0.769231
# 1   1.000000
# 2   0.833333
# 3   0.600000
# 4   0.800000
# ..       ...
# 95  1.000000
# 96  1.000000
# 97  1.000000
# 98  1.000000
# 99  0.666667
#
# [100 rows x 13 columns]

# %%
print(f"Overlap:   {new_df['overlap'].mean():.4f} (Intersection divided by the size of the larger set)")
print(f"Jaccard:   {new_df['jaccard'].mean():.4f} (Intersection divided by the size of the union)")
print(f"Precision: {new_df['precision'].mean():.4f} (Fraction of predicted ingredients that are correct)")
print(f"Recall:    {new_df['recall'].mean():.4f} (Fraction of actual ingredients that were predicted)")
print(f"F1:        {new_df['f1'].mean():.4f} (Harmonic mean of precision and recall)")
# Out:
# Overlap:   0.8744 (Intersection divided by the size of the larger set)
# Jaccard:   0.8104 (Intersection divided by the size of the union)
# Precision: 0.8834 (Fraction of predicted ingredients that are correct)
# Recall:    0.8756 (Fraction of actual ingredients that were predicted)
# F1:        0.8791 (Harmonic mean of precision and recall)
