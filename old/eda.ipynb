# %%
# !pip install --upgrade pip -q
# !pip install psycopg2-binary -q
# !pip install SQLAlchemy -q
# !pip install spacy -q
# !python -m spacy download en_core_web_sm -q
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import socket

import pandas as pd
from sqlalchemy import create_engine

# %%
host = "awesome-hw.sdsc.edu"
port = 5432  # PostgreSQL default port

try:
    socket.create_connection((host, port), timeout=5)
    print("✅ Host is reachable — network connection works.")
except Exception as e:
    print("❌ Cannot reach host:", e)
# Out:
# ✅ Host is reachable — network connection works.

# %%
# Connection parameters
host = "awesome-hw.sdsc.edu"
port = 5432
database = "nourish"
user = "akrish"  # <–– given this by TA
password = "dse203#2025"  # <–– your PostgreSQL password

# Create the connection engine
engine = create_engine(f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}")

# Test the connection
try:
    with engine.connect() as conn:
        print("✅ Connected successfully!")
except Exception as e:
    print("❌ Connection failed:", e)
# Out:
# ✅ Connected successfully!

# %%
query = """
        SELECT table_name
        FROM information_schema.tables
        WHERE table_schema = 'public'
        ORDER BY table_name; \
        """

tables = pd.read_sql(query, engine)
print(tables)
# Out:
#                                            table_name
# 0                                       ArcGIS_Schema
# 1                                             CA-CDFI
# 2    ESRI_SD_County_Tract_Level_Market_Potential_Data
# 3            ESRI_SD_County_Tract_Level_business_data
# 4        ESRI_SD_County_Tract_Level_consumer_spending
# ..                                                ...
# 138          usda_2022_food_calorie_conversion_factor
# 139                           usda_2022_food_portions
# 140          usda_2022_food_protein_conversion_factor
# 141                         usda_2022_nutrient_master
# 142                                             users
#
# [143 rows x 1 columns]

# %%
# query 50 rows
query = "SELECT * FROM \"FoodKG\" LIMIT 50;"  # quotes protect uppercase table names

df = pd.read_sql(query, engine)

# display nicely
pd.set_option('display.max_columns', None)  # show all columns
pd.set_option('display.max_rows', 50)  # show up to 50 rows
display(df)
# Out:
#          id                                              title  \
# 0   2226888                    Festive Ham Sushi for Girls Day
# 1   2226894                           Blue Trout Luchow Recipe
# 2   2226901                                 Arias Mac n Cheese
# 3   2226904                     Crispy Tempura Battered Shrimp
# 4   2226911                                       Tofu Muffins
# 5   2227007                  ""fried" Brown Rice (Vegetarian)"
# 6   2227017                      Another Mixed Berry Smoothie!
# 7   2226919                               Rocky Road Ice Cream
# 8   2226935                                    Cancun Salmon q
# 9   2226950                            Roast Pork and Potatoes
# 10  2226954                              Tropical Vanilla Cake
# 11  2227018                                      The BEST Rice
# 12  2226959                            Halloween Haunted House
# 13  2226983                                   Tuna Fish Delite
# 14  2226984                               Blueberry Lemon Loaf
# 15  2226988  Best Of Bridge Cajun Bread Pudding And Rum Sau...
# 16  2227005                                 Roasted Vegetables
# 17  2227006  1988 3rd Place Gloria Heeters Best Gingerbread...
# 18  2227059                      Sweet Onion and Kabocha Salad
# 19  2227031                        Baked Chicken a la Joe Dogs
# 20  2227034                                   Football Stadium
# 21  2227043  Low-Cal Cellophane Noodles Simmered with Mushr...
# 22  2227044                           Beckies Peach Jello Cake
# 23  2227052                                  Pistachio Squares
# 24  2227058                       Baked Chicken in Honey Sauce
# 25  2227063                       Dutch Oven -- Nine Mile Stew
# 26  2227066                             SMore Sandwich Cookies
# 27  2227075                                    Wild Rice Salad
# 28  2227078                              Baked Caramel Custard
# 29  2227087          Our Familys Favorite Pear and Almond Tart
# 30  2227088  Shrimp or Chicken Lettuce Wraps with Creamy Ca...
# 31  2227089                     Creamy Grilled Turkey Sandwich
# 32  2227093         Basic Tomato Sauce (Tomato Leather) Recipe
# 33  2227095  Lindas Delightful Creamy Chicken and Potato So...
# 34  2227103        ~Shamroks~ Catholic Girls Jewish Apple Cake
# 35  2227106                                  Turkey Tetrazzini
# 36  2227114    Newspaper Nuts: Indian Spiced Nuts with Coconut
# 37  2227118                      Muffins with Fluffy Egg Salad
# 38  2227123                      Peppermint-Hot Cocoa in a Jar
# 39  2227126                    Pork Fillet With Apple and Leek
# 40  2227134             Easy Ribs with Sriracha Barbecue Sauce
# 41  2227275                Healthy and Nourishing Chilled Tofu
# 42  2227145                                   Thai Mussel Soup
# 43  2227147                                      Chinese Salad
# 44  2227150  Aunt Babys Iceberg Health Salad With Roasted B...
# 45  2227151                          Beef and Black Bean Chili
# 46  2227155                   Chipped Beef & Artichokes Recipe
# 47  2227156                 "Avocado, Tomato and Cheese Toast"
# 48  2227160  Roasted Double Rack of Pork with Morel Mushroo...
# 49  2227317                                            Beatnik
#
#                                           ingredients  \
# 0   [5 slice Roast ham slices, 3 Eggs, 6 Shiso lea...
# 1   [1/4 c. White vinegar, 2 Tbsp. Wine vinegar Ju...
# 2   [Kosher salt, 2 bags eggs noodles, 5 tablespoo...
# 3   [Vegetable oil, for frying, 2 pounds large shr...
# 4   [100 grams Firm tofu, 35 grams Sugar, 1 Egg, 1...
# 5   [2 cups instant brown rice, 12 cup frozen peas...
# 6   [2 cups frozen mixed berries, 1 12-2 cups mixe...
# 7   [1 1/2 cups whole milk, 1 1/2 cups heavy cream...
# 8   [1 (14 ounce) can unsweetened coconut milk, 1 ...
# 9   [2 (2 1/2 to 3-pound) boneless pork loins, Ext...
# 10  [1 cup BAKERS ANGEL FLAKE Coconut, divided, 4 ...
# 11  [1 Oil, 3 clove Garlic minced, 1 small onion d...
# 12  [2 each milk, 1 (5 oz.) PLANTERS CHEESE MANIA ...
# 13  [2 (6 ounce) cans tuna or 2 (6 ounce) cans tun...
# 14  [1 lemon, 1 tablespoon confectioners sugar, 3/...
# 15  [1/3 c. butter or possibly margarine, melted, ...
# 16  [1 small eggplant Safeway 1 ea For $1.28 thru ...
# 17  [1 c. Corn oil margarine, 1 c. Molasses, 1 c. ...
# 18  [1/4 medium Sweet onion, 1/4 Kabocha squash, 5...
# 19  [4 each chicken breasts (remove skin but leave...
# 20  [1 can (16 oz.) TACO BELL Refried Beans, 1 pkg...
# 21  [3 packs worth Several types of mushrooms, suc...
# 22  [1 box white cake mix, 1 can halved or sliced ...
# 23  [1 cup flour, 12 cup butter or 12 cup margarin...
# 24  [14 cup margarine, 14 cup honey, 14 cup orange...
# 25  [1 pound stewing beef, 1 each beef stew season...
# 26  [1 pkg. (8 oz.) PHILADELPHIA Cream Cheese, sof...
# 27  [2 cups lundbergs wild rice mix, 3 cups vegeta...
# 28  [1/2 cup brown sugar, 2 cups skim milk, 1/4 cu...
# 29  [63 grams Unsalted butter, 63 grams Sugar, 1/2...
# 30  [2 hearts romaine lettuce, 1 pound jumbo fully...
# 31  [2 slices bread, 2 teaspoons butter or 2 teasp...
# 32  [1/3 c. Onion, minced very fine, 2 x Garlic cl...
# 33  [1 (20 ounce) bag Simply Potatoes, diced (any ...
# 34  [5 medium Gala Apples, 5 tbsp Sugar, 2 1/2 tsp...
# 35  [1 (pkg. (16 oz.) egg noodles, 1 can (10-3/4 o...
# 36  [1 cup unsalted roasted peanuts, 1 cup chopped...
# 37  [2 English muffins, 2 Eggs, 1 to 2 leaves Cabb...
# 38  [1/2 cup Rich Milk Chocolate Flavor NESTLE Hot...
# 39  [800 -1000 g pork fillets (Read note above), 2...
# 40  [2 lb. pork spareribs, 1 tsp. each garlic powd...
# 41  [2 blocks of 75 grams each Silken tofu (firm t...
# 42  [2 cups white wine, 2 tablespoons lemon juice,...
# 43  [1 head cabbage, Napa, sliced thin, 1 bunch sc...
# 44  [12 lb butternut squash, cut into fingers and ...
# 45  [1 lb. lean ground beef King Soopers 1 lb For ...
# 46  [3 tbsp. butter, 1 jar or possibly pkg. chippe...
# 47  [2 slices bread, thickly sliced, 1 avocado, sl...
# 48  [3 large garlic cloves, 2 shallots, quartered,...
# 49  [24 ounces bourbon, 12 ounces tawny port, 8 ou...
#
#                                            directions  \
# 0   [I used a cake pan., Line it with ham., Mix fl...
# 1   [Combine all the ingredients except the trout ...
# 2   [Preheat the oven to 350 degrees F., Bring a l...
# 3   [In a deep-fryer or large Dutch oven, pour oil...
# 4   [Blend tofu with a hand mixer until soft, then...
# 5   [Start by cooking the instant brown rice accor...
# 6   [Mix all ingredients in a blender until its th...
# 7   [Place the milk, cream and 1/4 cup of the suga...
# 8   [In a 9x13-inch baking dish combine coconut mi...
# 9   [Serve with Creamy Mushrooms and Kale recipe f...
# 10  [Preheat oven to 325F., Place 1/4 cup of the c...
# 11  [heat pot with oil, saute onions, garlic seaso...
# 12  [Rinse and dry milk or juice, snack and sour c...
# 13  [Drain tuna, dont have to wash off the oil-pac...
# 14  [Preheat oven to 350 degrees F (175 degrees C)...
# 15  [To Make Pudding:Pour a small amount of the me...
# 16  [Preheat oven to 425F., Cover 2 baking sheets ...
# 17  [Preparation Time: 25 min, Chilling Time: 8 hr...
# 18  [Slice the kabocha into pieces, put it in a he...
# 19  [Place chicken breasts, facing bone down, in a...
# 20  [Spread beans into 10x8-inch rectangle on larg...
# 21  [Rehydrate the koya tofu in hot water., Rehydr...
# 22  [Follow directions on cake mix., Bake and let ...
# 23  [FIRST LAYER:., Mix together flour, butter and...
# 24  [Preheat oven to 375F., In a 9x13-inch baking ...
# 25  [Put enough oil in the oven to cover the botto...
# 26  [Preheat oven to 325 degrees F. Beat cream che...
# 27  [1., Cook the rice: rinse wild rice under runn...
# 28  [Preheat oven to 350 degrees F., Melt brown su...
# 29  [Sift the flour, baking powder and salt severa...
# 30  [Cut bottoms off the romaine and cut the heads...
# 31  [Preheat a saute or grill pan on medium heat.,...
# 32  [Saute/fry the onion and garlic together in th...
# 33  [In a large pot, empty both cans of soup., Fil...
# 34  [Preheat oven to 350AF., In Medium Bowl: Pare ...
# 35  [Cook noodles according to package directions....
# 36  [Preheat the oven to 250 degrees F. Line a bak...
# 37  [Here are the ingredients., I usually prepare ...
# 38  [Layer ingredients in clean 1-1/2 cup jar with...
# 39  [Preheat oven to 200 degrees Celsius., Place p...
# 40  [Heat oven to 350F., Place ribs in single laye...
# 41  [Roughly chop up the kimchi., Add natto which ...
# 42  [In large pot with lid, combine wine, lemon ju...
# 43  [Break up noodles in package before opening.di...
# 44  [Roast the butternut fingers: Set oven at 350 ...
# 45  [Brown meat with onions and garlic in Dutch ov...
# 46  [Prepare chipped beef with flour, lowfat milk,...
# 47  [Toast bread under a hot grill until golden., ...
# 48  [Chop garlic and quartered shallots in mini pr...
# 49  [In a pitcher, combine all of the ingredients ...
#
#                                                  link     source  \
# 0   cookpad.com/us/recipes/142761-festive-ham-sush...  Recipes1M
# 1    cookeatshare.com/recipes/blue-trout-luchow-87646  Recipes1M
# 2   www.foodnetwork.com/recipes/aria-kagan/arias-m...  Recipes1M
# 3   www.foodnetwork.com/recipes/paula-deen/crispy-...  Recipes1M
# 4          cookpad.com/us/recipes/156535-tofu-muffins  Recipes1M
# 5   www.food.com/recipe/fried-brown-rice-vegetaria...  Recipes1M
# 6   www.food.com/recipe/another-mixed-berry-smooth...  Recipes1M
# 7        www.cookstr.com/recipes/rocky-road-ice-cream  Recipes1M
# 8          www.food.com/recipe/cancun-salmon-q-226343  Recipes1M
# 9   www.foodnetwork.com/recipes/rachael-ray/roast-...  Recipes1M
# 10  www.kraftrecipes.com/recipes/tropical-vanilla-...  Recipes1M
# 11        cookpad.com/us/recipes/336064-the-best-rice  Recipes1M
# 12  www.kraftrecipes.com/recipes/halloween-haunted...  Recipes1M
# 13        www.food.com/recipe/tuna-fish-delite-248602  Recipes1M
# 14        allrecipes.com/recipe/blueberry-lemon-loaf/  Recipes1M
# 15  cookeatshare.com/recipes/best-of-bridge-cajun-...  Recipes1M
# 16  www.kraftrecipes.com/recipes/roasted-vegetable...  Recipes1M
# 17  cookeatshare.com/recipes/1988-3rd-place-gloria...  Recipes1M
# 18  cookpad.com/us/recipes/156429-sweet-onion-and-...  Recipes1M
# 19  recipeland.com/recipe/v/baked-chicken-joe-dogs...  Recipes1M
# 20  www.kraftrecipes.com/recipes/football-stadium-...  Recipes1M
# 21  cookpad.com/us/recipes/143950-low-cal-cellopha...  Recipes1M
# 22  cookpad.com/us/recipes/347109-beckies-peach-je...  Recipes1M
# 23       www.food.com/recipe/pistachio-squares-366862  Recipes1M
# 24  www.food.com/recipe/baked-chicken-in-honey-sau...  Recipes1M
# 25  recipeland.com/recipe/v/dutch-oven-nine-mile-s...  Recipes1M
# 26  www.kraftrecipes.com/recipes/smore-sandwich-co...  Recipes1M
# 27         www.food.com/recipe/wild-rice-salad-504917  Recipes1M
# 28  www.foodnetwork.com/recipes/baked-caramel-cust...  Recipes1M
# 29  cookpad.com/us/recipes/169075-our-familys-favo...  Recipes1M
# 30  www.foodnetwork.com/recipes/rachael-ray/shrimp...  Recipes1M
# 31  www.food.com/recipe/creamy-grilled-turkey-sand...  Recipes1M
# 32  cookeatshare.com/recipes/basic-tomato-sauce-to...  Recipes1M
# 33  www.food.com/recipe/lindas-delightful-creamy-c...  Recipes1M
# 34  cookpad.com/us/recipes/339958-shamroks-catholi...  Recipes1M
# 35  www.kraftrecipes.com/recipes/turkey-tetrazzini...  Recipes1M
# 36  www.foodnetwork.com/recipes/aarti-sequeira/new...  Recipes1M
# 37  cookpad.com/us/recipes/169853-muffins-with-flu...  Recipes1M
# 38  www.kraftrecipes.com/recipes/peppermint-hot-co...  Recipes1M
# 39  www.food.com/recipe/pork-fillet-with-apple-and...  Recipes1M
# 40  www.kraftrecipes.com/recipes/easy-ribs-srirach...  Recipes1M
# 41  cookpad.com/us/recipes/169861-healthy-and-nour...  Recipes1M
# 42     recipeland.com/recipe/v/thai-mussel-soup-32513  Recipes1M
# 43           www.food.com/recipe/chinese-salad-429673  Recipes1M
# 44  www.food.com/recipe/aunt-babys-iceberg-health-...  Recipes1M
# 45  www.kraftrecipes.com/recipes/beef-black-bean-c...  Recipes1M
# 46  cookeatshare.com/recipes/chipped-beef-artichok...  Recipes1M
# 47  www.kraftrecipes.com/recipes/avocado-tomato-ch...  Recipes1M
# 48  cookeatshare.com/recipes/roasted-double-rack-o...  Recipes1M
# 49  www.foodandwine.com/recipes/beatnik-cocktails-...  Recipes1M
#
#                                                   ner
# 0   [ham slices, Eggs, leaves, salmon, cheese, usi...
# 1   [White vinegar, vinegar Juice, Water, Salt, Ba...
# 2   [Kosher salt, eggs noodles, unsalted butter, o...
# 3   [Vegetable oil, shrimp, all-purpose flour, wat...
# 4      [tofu, Sugar, Egg, Salt, Baking powder, flour]
# 5   [instant brown rice, carrot, soy sauce, egg wh...
# 6                  [mixed fruit sherbet, grape juice]
# 7   [milk, heavy cream, white sugar, egg yolks, va...
# 8   [unsweetened coconut milk, marinade, salmon, o...
# 9   [pork loins, Extra-virgin olive oil, salt, Fre...
# 10  [S ANGEL, PHILADELPHIA Cream Cheese, butter, s...
# 11  [Oil, Garlic, onion, tomtoe, chicken, favorite...
# 12  [milk, S, vanilla frosting, OREO Chocolate, lo...
# 13  [tuna, scallion, lemon juice, cheddar cheese, ...
# 14  [lemon, sugar, white sugar, butter, eggs, sour...
# 15  [butter, bread, sugar, vanilla, nutmeg, cinnam...
# 16  [red peppers, zucchini, jalapeno peppers, onio...
# 17  [Corn oil margarine, Molasses, Sugar, Egg, Flo...
# 18            [Sweet onion, squash, Mayonnaise, Salt]
# 19  [chicken breasts, black pepper, garlic, oregan...
# 20  [TACO, Four Cheese, S, TACO, guacamole, chedda...
# 21  [worth Several types, noodles, dofu, Carrot, G...
# 22  [white cake mix, peaches, eggs, vegetable oil,...
# 23  [flour, butter, white sugar, sugar, cream chee...
# 24  [margarine, honey, orange juice, lemon juice, ...
# 25  [stewing beef, beef stew seasoning package, on...
# 26  [PHILADELPHIA Cream Cheese, powdered sugar, bu...
# 27  [lundbergs, vegetable broth, mushroom, carrots...
# 28    [brown sugar, milk, sugar, salt, eggs, vanilla]
# 29  [butter, Sugar, Egg, flour, Baking powder, Sal...
# 30  [hearts romaine lettuce, shrimp, rotisserie ch...
# 31  [bread, butter, cream cheese, mayonnaise, ched...
# 32  [Onion, Garlic, Extra virgin olive oil, Margar...
# 33  [Potatoes, chicken, Campbells Cream, Campbells...
# 34  [Apples, Sugar, Cinnamon, Flour, Sugar, Baking...
# 35  [egg noodles, condensed cream, milk, water, tu...
# 36  [peanuts, pecans, shredded coconut, vegetable ...
# 37  [muffins, Eggs, Cabbage, Mayonnaise, Milk, Sal...
# 38  [Milk Chocolate Flavor, mints, Chocolate, JET-...
# 39  [pork, water, instant chicken, leeks, garlic, ...
# 40  [pork spareribs, garlic, ground black, Barbecu...
# 41        [pack Natto, Cauldron, handful, Sesame oil]
# 42  [white wine, lemon juice, onions, bay leaves, ...
# 43  [cabbage, scallion, packagesramen soup noodles...
# 44  [butternut squash, iceberg lettuce, cucumbers,...
# 45  [lean ground beef, onions, garlic, chili powde...
# 46  [butter, chipped beef, flour, milk, Pepper, so...
# 47  [bread, avocado, tomato, Easy Cheese Cream Che...
# 48  [garlic, shallots, olive oil, fresh sage, fres...
# 49  [bourbon, tawny port, amaro, bitters, orange t...

# %%
# Only fetch the column names without data
columns = pd.read_sql("SELECT * FROM \"FoodKG\" LIMIT 0;", engine).columns
print(columns)
# Out:
# Index(['id', 'title', 'ingredients', 'directions', 'link', 'source', 'ner'], dtype='object')

# %%
import spacy
import re

nlp = spacy.load("en_core_web_sm")

# Common measurement units to remove
units = ['c', 'cup', 'cups', 'tbsp', 'tsp', 'oz', 'g', 'kg', 'ml', 'l', 'pinch', 'slice', 'clove', 'cloves']
pattern_units = r'\b(?:' + '|'.join(units) + r')\b'

# Process every recipe
all_cleaned_ingredients = []

for ingredient_list in df['ingredients']:
    recipe_ingredients = []
    for ing in ingredient_list:
        # lowercase
        ing_clean = ing.lower()
        # remove numbers and fractions
        ing_clean = re.sub(r'\d+\/\d+|\d+', '', ing_clean)
        # remove units
        ing_clean = re.sub(pattern_units, '', ing_clean)
        # remove punctuation and extra spaces
        ing_clean = re.sub(r'[^a-zA-Z\s]', '', ing_clean)
        ing_clean = re.sub(r'\s+', ' ', ing_clean).strip()

        # use SpaCy to extract nouns
        doc = nlp(ing_clean)
        nouns = [token.text for token in doc if token.pos_ == 'NOUN']

        if nouns:
            recipe_ingredients.append(' '.join(nouns))

    all_cleaned_ingredients.append(recipe_ingredients)

# Add it back to the dataframe as a new column
df['cleaned_ingredients'] = all_cleaned_ingredients

# Display first 5 recipes
df[['ingredients', 'cleaned_ingredients']].head()
# Out:
#                                          ingredients  \
# 0  [5 slice Roast ham slices, 3 Eggs, 6 Shiso lea...
# 1  [1/4 c. White vinegar, 2 Tbsp. Wine vinegar Ju...
# 2  [Kosher salt, 2 bags eggs noodles, 5 tablespoo...
# 3  [Vegetable oil, for frying, 2 pounds large shr...
# 4  [100 grams Firm tofu, 35 grams Sugar, 1 Egg, 1...
#
#                                  cleaned_ingredients
# 0  [roast slices, eggs, shiso, salmon storebought...
# 1  [vinegar, wine vinegar juice lemon, water, sal...
# 2  [salt, eggs noodles, tablespoons butter, onion...
# 3  [vegetable oil, shrimp tails, flour, water, eg...
# 4               [sugar, egg, teaspoon powder, flour]

# %%
query = 'SELECT COUNT(*) AS total_rows FROM "FoodKG";'

result = pd.read_sql(query, engine)
print(result["total_rows"].iloc[0])
# Out:
# 2231142

# %%
query = """
SELECT
    id,
    title,
    ingredients,
    ner
FROM
    "FoodKG"
WHERE
    id IS NOT NULL AND
    title IS NOT NULL AND
    ingredients IS NOT NULL AND
    ner IS NOT NULL
LIMIT 500;
"""

result = pd.read_sql(query, engine)
print(result)
# Out:
#           id                                              title  \
# 0    2226888                    Festive Ham Sushi for Girls Day
# 1    2226894                           Blue Trout Luchow Recipe
# 2    2226901                                 Arias Mac n Cheese
# 3    2226904                     Crispy Tempura Battered Shrimp
# 4    2226911                                       Tofu Muffins
# ..       ...                                                ...
# 495  2229877                                      Snickers Cake
# 496  2229887                               Vegan Banana Muffins
# 497  2229891                                         Royal Jack
# 498  2229894  "Mussel, Fish and Butternut Chowder ... or Stew!"
# 499  2229899                   Low Cal Flourless Marble Pudding
#
#                                            ingredients  \
# 0    [5 slice Roast ham slices, 3 Eggs, 6 Shiso lea...
# 1    [1/4 c. White vinegar, 2 Tbsp. Wine vinegar Ju...
# 2    [Kosher salt, 2 bags eggs noodles, 5 tablespoo...
# 3    [Vegetable oil, for frying, 2 pounds large shr...
# 4    [100 grams Firm tofu, 35 grams Sugar, 1 Egg, 1...
# ..                                                 ...
# 495  [1 (12 ounce) box devils food cake mix, plus i...
# 496  [2 tablespoons sugar, 1 egg substitute, 1 teas...
# 497  [Ice, 2 ounces applejack (recommended: Lairds ...
# 498  [2 lbs mussels on the half shell (1 kg, or 1.2...
# 499  [vanilla batter, 150 g light cream cheese, 80 ...
#
#                                                    ner
# 0    [ham slices, Eggs, leaves, salmon, cheese, usi...
# 1    [White vinegar, vinegar Juice, Water, Salt, Ba...
# 2    [Kosher salt, eggs noodles, unsalted butter, o...
# 3    [Vegetable oil, shrimp, all-purpose flour, wat...
# 4       [tofu, Sugar, Egg, Salt, Baking powder, flour]
# ..                                                 ...
# 495  [cake mix, condensed milk, caramel ice cream, ...
# 496  [sugar, egg substitute, vanilla, soymilk, bana...
# 497  [applejack, freshly squeezed lemon juice, home...
# 498  [mussels, white fish, onion, potatoes, buttern...
# 499  [vanilla batter, light cream cheese, Splenda s...
#
# [500 rows x 4 columns]

# %%
query = """
SELECT
    id,
    name
FROM
    usda_2022_nutrient_master
WHERE
    id IS NOT NULL AND
    name IS NOT NULL
LIMIT 500;
"""

result = pd.read_sql(query, engine)
print(result)
# Out:
#        id                                        name
# 0    2047            Energy (Atwater General Factors)
# 1    2048           Energy (Atwater Specific Factors)
# 2    1001                                      Solids
# 3    1002                                    Nitrogen
# 4    1003                                     Protein
# ..    ...                                         ...
# 469  2061                         Ergosta-7,22-dienol
# 470  2062                          Ergosta-5,7-dienol
# 471  2063                                  Verbascose
# 472  2064                            Oligosaccharides
# 473  2065  Low Molecular Weight Dietary Fiber (LMWDF)
#
# [474 rows x 2 columns]

# %%
query = """
SELECT
    fdc_id,
    description
FROM
    usda_2022_food_branded_experimental
WHERE
    fdc_id IS NOT NULL AND
    description IS NOT NULL
LIMIT 500;
"""

result = pd.read_sql(query, engine)
print(result)
# Out:
#       fdc_id                                        description
# 0    1105904                         WESSON Vegetable Oil 1 GAL
# 1    1105905                                 SWANSON BROTH BEEF
# 2    1105906           CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER
# 3    1105907        CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI
# 4    1105898  Discrepancy between the Atwater factor predict...
# ..       ...                                                ...
# 495  1106392  MEATLOAF WITH PORTOBELLO MUSHROOM GRAVY MEATLO...
# 496  1106393  CRUSTLESS CHICKEN POT PIE WHITE MEAT CHICKEN, ...
# 497  1106394                                          BBQ SAUCE
# 498  1106395           THAI-STYLE COCONUT CHICKEN, MEDIUM SPICY
# 499  1106396                                    SHRIMP PAD THAI
#
# [500 rows x 2 columns]

# %%
query = """
SELECT
    id,
    fdc_id,
    nutrient_id
FROM
    usda_2022_branded_food_nutrients
WHERE
    id IS NOT NULL AND
    fdc_id IS NOT NULL AND
    nutrient_id IS NOT NULL
LIMIT 500;
"""

result = pd.read_sql(query, engine)
print(result)
# Out:
#            id   fdc_id  nutrient_id
# 0    13706913  1105904         1003
# 1    13706914  1105904         1004
# 2    13706915  1105904         1005
# 3    13706924  1105904         1110
# 4    13706918  1105904         1079
# ..        ...      ...          ...
# 495  13707096  1105935         2000
# 496  13707094  1105935         1005
# 497  13707101  1105935         1093
# 498  13707100  1105935         1092
# 499  13707099  1105935         1089
#
# [500 rows x 3 columns]

# %%
query = """
SELECT
    fdc_id,
    description
FROM
    usda_2022_food_branded_experimental
LIMIT 500;
"""

result = pd.read_sql(query, engine)
print(result)
# Out:
#       fdc_id                                        description
# 0    1105904                         WESSON Vegetable Oil 1 GAL
# 1    1105905                                 SWANSON BROTH BEEF
# 2    1105906           CAMPBELL'S SLOW KETTLE SOUP CLAM CHOWDER
# 3    1105907        CAMPBELL'S SLOW KETTLE SOUP CHEESE BROCCOLI
# 4    1105898  Discrepancy between the Atwater factor predict...
# ..       ...                                                ...
# 495  1106392  MEATLOAF WITH PORTOBELLO MUSHROOM GRAVY MEATLO...
# 496  1106393  CRUSTLESS CHICKEN POT PIE WHITE MEAT CHICKEN, ...
# 497  1106394                                          BBQ SAUCE
# 498  1106395           THAI-STYLE COCONUT CHICKEN, MEDIUM SPICY
# 499  1106396                                    SHRIMP PAD THAI
#
# [500 rows x 2 columns]

# %%
query = """
SELECT
    id,
    fdc_id,
    nutrient_id
FROM
    usda_2022_branded_food_nutrients
LIMIT 500;
"""

result = pd.read_sql(query, engine)
print(result)
# Out:
#            id   fdc_id  nutrient_id
# 0    13706913  1105904         1003
# 1    13706914  1105904         1004
# 2    13706915  1105904         1005
# 3    13706924  1105904         1110
# 4    13706918  1105904         1079
# ..        ...      ...          ...
# 495  13707096  1105935         2000
# 496  13707094  1105935         1005
# 497  13707101  1105935         1093
# 498  13707100  1105935         1092
# 499  13707099  1105935         1089
#
# [500 rows x 3 columns]
