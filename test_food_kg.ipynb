# %%
import ast
import json

import pandas as pd

# %%
# convert "['a','b']" to a set {'a', 'b'}
def to_set(x):
    list_string = json.loads(x)
    list_raw = ast.literal_eval(list_string)
    return set(list_raw)

# %%
# Read the CSV
output_df = pd.read_csv("sample/FoodKG_ingredients_normalized.csv")
test_df = pd.read_csv("TEST/TEST_FoodKG_ingredients_normalized.csv")
# Rename test column so we don't clash on merge
test_df_renamed = test_df.rename(columns={"ingredients_normalized": "ingredients_test"})
# Merge using test_df as the left df to keep its order
merged_df = test_df_renamed[["id", "ingredients_test"]].merge(
    output_df, on="id", how="inner"
)
merged_df.head()
# Out:
#    id                                   ingredients_test  \
# 0   0  "['brown sugar', 'evaporated milk', 'vanilla',...
# 1   1  "['chipped beef', 'chicken breast', 'cream of ...
# 2   2  "['corn', 'cream cheese', 'butter', 'garlic po...
# 3   3  "['whole chicken', 'chicken gravy', 'cream of ...
# 4   4  "['peanut butter', 'graham cracker', 'butter',...
#
#                                          ingredients  \
# 0  ['1 c. firmly packed brown sugar', '1/2 c. eva...
# 1  ['1 small jar chipped beef, cut up', '4 boned ...
# 2  ['2 (16 oz.) pkg. frozen corn', '1 (8 oz.) pkg...
# 3  ['1 large whole chicken', '2 (10 1/2 oz.) cans...
# 4  ['1 c. peanut butter', '3/4 c. graham cracker ...
#
#                               ingredients_normalized
# 0  "['brown sugar', 'evaporated milk', 'vanilla',...
# 1  "['chipped beef', 'chicken breast', 'cream of ...
# 2  "['corn', 'cream cheese', 'butter', 'garlic po...
# 3  "['chicken', 'chicken gravy', 'mushroom soup',...
# 4  "['peanut butter', 'graham cracker crumbs', 'b...

# %%
new_df = pd.DataFrame({
    "id": merged_df["id"],
    "ingredients": merged_df["ingredients"],
    "output_set": merged_df["ingredients_normalized"].apply(to_set),
    "test_set": merged_df["ingredients_test"].apply(to_set)
})
new_df.head()
# Out:
#    id                                        ingredients  \
# 0   0  ['1 c. firmly packed brown sugar', '1/2 c. eva...
# 1   1  ['1 small jar chipped beef, cut up', '4 boned ...
# 2   2  ['2 (16 oz.) pkg. frozen corn', '1 (8 oz.) pkg...
# 3   3  ['1 large whole chicken', '2 (10 1/2 oz.) cans...
# 4   4  ['1 c. peanut butter', '3/4 c. graham cracker ...
#
#                                           output_set  \
# 0  {pecan, evaporated milk, brown sugar, vanilla,...
# 1  {chicken breast, cream of mushroom soup, sour ...
# 2  {salt, cream cheese, garlic powder, pepper, bu...
# 3  {stuffing, cheese, mushroom soup, chicken, chi...
# 4  {powdered sugar, chocolate chips, peanut butte...
#
#                                             test_set
# 0  {rice biscuit, pecan, evaporated milk, margari...
# 1  {chicken breast, cream of mushroom soup, sour ...
# 2  {salt, cream cheese, garlic powder, black pepp...
# 3  {stuffing, whole chicken, cheese, cream of mus...
# 4  {powdered sugar, chocolate chip, peanut butter...

# %%
def precision_recall_f1_per_row(row):
    pred = row["output_set"]
    true = row["test_set"]

    tp = len(pred & true)
    fp = len(pred - true)
    fn = len(true - pred)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0.0

    return pd.Series({"precision": precision, "recall": recall, "f1": f1})

# %%
# Elements that differ
new_df["only_in_output"] = new_df["output_set"] - new_df["test_set"]
new_df["only_in_test"] = new_df["test_set"] - new_df["output_set"]
# intersection count
new_df["intersection_size"] = new_df.apply(
    lambda row: len(row["output_set"] & row["test_set"]), axis=1
)

# union count
new_df["union_size"] = new_df.apply(
    lambda row: len(row["output_set"] | row["test_set"]), axis=1
)

# accuracy = intersection / larger_set
new_df["accuracy"] = new_df.apply(
    lambda row: (
        len(row["output_set"] & row["test_set"]) /
        max(len(row["output_set"]), len(row["test_set"]))
        if max(len(row["output_set"]), len(row["test_set"])) > 0
        else 0
    ),
    axis=1
)

# Jaccard similarity (intersection / union)
new_df["jaccard"] = new_df.apply(
    lambda row: (
        len(row["output_set"] & row["test_set"]) /
        len(row["output_set"] | row["test_set"])
        if len(row["output_set"] | row["test_set"]) > 0
        else 0
    ),
    axis=1
)

new_df[["precision", "recall", "f1"]] = new_df.apply(precision_recall_f1_per_row, axis=1)

# %%
new_df.head(100)
# Out:
#     id                                        ingredients  \
# 0    0  ['1 c. firmly packed brown sugar', '1/2 c. eva...
# 1    1  ['1 small jar chipped beef, cut up', '4 boned ...
# 2    2  ['2 (16 oz.) pkg. frozen corn', '1 (8 oz.) pkg...
# 3    3  ['1 large whole chicken', '2 (10 1/2 oz.) cans...
# 4    4  ['1 c. peanut butter', '3/4 c. graham cracker ...
# ..  ..                                                ...
# 95  95  ['3 (1 lb.) cans pork and beans', '1/2 c. bell...
# 96  96  ['2 c. diced cooked chicken', '2 Tbsp. shorten...
# 97  97  ['8 to 10 juicy oranges, peeled and diced', '1...
# 98  98  ['1 c. creamy peanut butter', '1 c. sugar', '1...
# 99  99  ['1 box yellow cake mix', '2 eggs', '1/3 c. so...
#
#                                            output_set  \
# 0   {pecan, evaporated milk, brown sugar, vanilla,...
# 1   {chicken breast, cream of mushroom soup, sour ...
# 2   {salt, cream cheese, garlic powder, pepper, bu...
# 3   {stuffing, cheese, mushroom soup, chicken, chi...
# 4   {powdered sugar, chocolate chips, peanut butte...
# ..                                                ...
# 95  {salt, ground beef, bell pepper, black pepper,...
# 96  {carrot, ginger, pineapple, green pepper, chic...
# 97  {orange juice, cherry, pecan, orange, sugar, c...
# 98                        {sugar, peanut butter, egg}
# 99  {bits o brickle, pecan, yellow cake mix, milk,...
#
#                                              test_set  \
# 0   {rice biscuit, pecan, evaporated milk, margari...
# 1   {chicken breast, cream of mushroom soup, sour ...
# 2   {salt, cream cheese, garlic powder, black pepp...
# 3   {stuffing, whole chicken, cheese, cream of mus...
# 4   {powdered sugar, chocolate chip, peanut butter...
# ..                                                ...
# 95  {salt, ground beef, bell pepper, black pepper,...
# 96  {carrot, ginger, pineapple, green pepper, chic...
# 97  {orange juice, cherry, pecan, orange, sugar, c...
# 98                        {sugar, peanut butter, egg}
# 99  {toffee bit, pecan, milk, margarine, yellow ca...
#
#                               only_in_output  \
# 0                    {shredded rice biscuit}
# 1                                         {}
# 2                                   {pepper}
# 3                   {mushroom soup, chicken}
# 4   {graham cracker crumbs, chocolate chips}
# ..                                       ...
# 95                                        {}
# 96                                        {}
# 97                                        {}
# 98                                        {}
# 99          {bits o brickle, soft margarine}
#
#                                only_in_test  intersection_size  union_size  \
# 0                 {rice biscuit, margarine}                  5           8
# 1                                        {}                  4           4
# 2                            {black pepper}                  5           7
# 3   {cream of mushroom soup, whole chicken}                  3           7
# 4          {chocolate chip, graham cracker}                  3           7
# ..                                      ...                ...         ...
# 95                                       {}                  9           9
# 96                                       {}                 14          14
# 97                                       {}                  6           6
# 98                                       {}                  3           3
# 99                  {toffee bit, margarine}                  4           8
#
#     accuracy   jaccard  precision    recall        f1
# 0   0.714286  0.625000   0.833333  0.714286  0.769231
# 1   1.000000  1.000000   1.000000  1.000000  1.000000
# 2   0.833333  0.714286   0.833333  0.833333  0.833333
# 3   0.600000  0.428571   0.600000  0.600000  0.600000
# 4   0.600000  0.428571   0.600000  0.600000  0.600000
# ..       ...       ...        ...       ...       ...
# 95  1.000000  1.000000   1.000000  1.000000  1.000000
# 96  1.000000  1.000000   1.000000  1.000000  1.000000
# 97  1.000000  1.000000   1.000000  1.000000  1.000000
# 98  1.000000  1.000000   1.000000  1.000000  1.000000
# 99  0.666667  0.500000   0.666667  0.666667  0.666667
#
# [100 rows x 13 columns]

# %%
print(f"Accuracy:  {new_df['accuracy'].mean():.4f}")
print(f"Jaccard:   {new_df['jaccard'].mean():.4f}")
print(f"Precision: {new_df['precision'].mean():.4f}")
print(f"Recall:    {new_df['recall'].mean():.4f}")
print(f"F1:        {new_df['f1'].mean():.4f}")
# Out:
# Accuracy:  0.8625
# Jaccard:   0.7944
# Precision: 0.8729
# Recall:    0.8637
# F1:        0.8679

# %%
# For LLM Tuning
all_missing_set = set(new_df["only_in_test"])
all_extra_set = set(new_df["only_in_output"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # For LLM Tuning
# ----> 2 all_missing_set = set(new_df["only_in_test"])
#       3 all_extra_set = set(new_df["only_in_output"])
#
# TypeError: unhashable type: 'set'
